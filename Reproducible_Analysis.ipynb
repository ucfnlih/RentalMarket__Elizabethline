# %% [markdown]
# # Reproduciable Analysis
#
# Initial code for FSDS Data+PolicyBriefing assignment
#
# By: Group BraCoChi

# %% [markdown]
# # The  Impact of ELizabeth Line in the Rental Market
# ## CASA0013: Foundations of Spatial Data Science
# ### Student Ids: ucfnant, ucfnlih, ucfnres, ucfnibj.

# %% [markdown]
# #### Due to MOODLE's limitation on file size, we cannot upload the zip file containing data and notebook. So we only upload notebook, and **the data can be obtained at this link :**
#
# https://liveuclac-my.sharepoint.com/:f:/g/personal/ucfnant_ucl_ac_uk/Ersm6BnLkIRIql8yV-MH-W0BltQ3jicpsB163Zfti87tbQ?e=E017k8

# %% [markdown]
# Note: It takes about 3min to run all the code.
#
# Github Link: https://github.com/brfelipealmeida/BraCoChi

# %% [markdown]
# # The  Impact of ELizabeth Line in the Rental Market

# %% [markdown]
# ## Coding Structure:
#
#     Libraries
#
#     1. Loading data
#       1.1 Loading price data
#       1.2 Loading Elizabeth line shapefile (stations and track)
#       1.3 Loading London borough data
#
#     2. Cleaning data
#       2.1 Reprojection
#       2.2 Cleaning Airbnb dataset
#         2.2.1 Dealing with NaNs and Nulls
#         2.2.2 Dealing with srings ('price')
#
#     3. Manipulating Data
#       3.1 Short-term rental data (Airbnb data)
#         3.1.1 Calculating global increasing rate
#         3.1.2 Calculating increasing rate by boroughs
#         3.1.3 Choosing the boroughs through which the Elizabeth Line passes
#       3.2 Long-term rental data
#         3.2.1 Calculating global increasing rate
#         3.2.2 Calculating increasing rate by boroughs
#         3.2.3 Choosing the boroughs through which the Elizabeth Line passes
#
#     4. Mapping
#        4.1 Short-term market (Airbnb)
#        4.2 Long-term market
#
#     5. Description analysis
#
#     6. Radius analysis for airbnb listing prices
#
#     7. Zone analysis for airbnb listing prices

# %% [markdown]
# ## Libraries

# %%
import os
import re
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
from matplotlib import colors
import shapely as sa
#from pandas_profiling import ProfileReport
import fiona
import requests

# %% [markdown]
# ## 1. Loading the data

# %% [markdown]
# ### Introduction
#
# This section is a pre-data preparation, which loads three datasets and three geographic files:
# - Long-term rental price
# - Airbnb 2020
# - Airbnb 2022
# - Shapefile of Elizabeth line station
# - Shapefile of Elizabeth line track
# - Shapefile of london borough

# %%
# check the current work path
os.getcwd()
# Out:
# '/home/jovyan/work'

# %%
path = os.getcwd() + '/raw_data/'
path
# Out:
# '/home/jovyan/work/raw_data/'

# %%
# Short-term rental price (Airbnb dataset for 2020 and 2022)
# Read in the raw data from 2022 Airbnb listing
airbnb_22_raw = pd.read_csv(path + 'Airbnb/raw/listings.csv')

# The raw data from 2020 Airbnb listing
airbnb_20_raw = pd.read_csv(path + 'Airbnb/raw/2020-08-24-listings.csv')
# Out:
# /tmp/ipykernel_2515/858560840.py:6: DtypeWarning: Columns (2,22,36,41,45,46,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   airbnb_20_raw = pd.read_csv(path + 'Airbnb/raw/2020-08-24-listings.csv')

# %%
# Long-term rental price
longterm_rental_raw = pd.read_csv(path + 'Long-term data (rental price & house price)/rent_price_borough.csv')

# The London excluding MHW boundries
London_ex_raw = gpd.read_file(path + 'statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp')

# Load the shape files
# The OA London boundaries
London_raw = gpd.read_file(path + 'statistical-gis-boundaries-london/ESRI/OA_2011_London_gen_MHW.shp')
# load the Elizabeth Line stations shape files
el_station_raw = gpd.read_file(path + 'Elizabeth_line_shapefile/CRL_Stations.shp')
# load the Elizabeth Line track shape files
el_track_raw = gpd.read_file(path + 'Elizabeth_line_shapefile/CRL_Track.shp')

# %%
# Load the TFL fare zones data (6 zones)
zones_raw = pd.read_csv(path + 'MyLondon_fare_zone_OA.csv')

# %% [markdown]
# ### 1.1 Loading price data

# %%
# Long-term rental price (per month, median price, by borough)
longterm_rental = longterm_rental_raw.copy()

# Short-term rental price (Airbnb dataset for 2020 and 2022)
airbnb_2020 = airbnb_20_raw.copy()
airbnb_2022 = airbnb_22_raw.copy()

# %% [markdown]
# ### 1.2 Loading Elizabeth line shapefile (stations and track)

# %%
# Loading stations shapefile
stations = el_station_raw.copy()
stations.head()    
stations.plot()

print(stations.head())
# Out:
#    OBJECTID   STATION_NA  SIZE_ SE_ANNO_CA                       geometry
# 0         1  Forest Gate  Small       None  POINT (540409.113 185311.628)
# 1         2   Manor Park  Small       None  POINT (541906.079 185683.241)
# 2         3       Ilford  Small       None  POINT (543515.859 186487.354)
# 3         4  Seven Kings  Small       None  POINT (545384.047 187089.399)
# 4         5    Goodmayes  Small       None  POINT (546470.589 187325.404)

# %% [markdown]
# ##### Assigning multi or mono station connections

# %%
#Creating blsnk column
stations['con'] = np.nan

# %%
#Mono multi conection
stations['con'].iloc[0,] = "Multi"
stations['con'].iloc[1,] = "Mono"
stations['con'].iloc[2,] = "Mono"
stations['con'].iloc[3,] = "Mono"
stations['con'].iloc[4,] = "Mono"
stations['con'].iloc[5,] = "Mono"
stations['con'].iloc[6,] = "Multi"
stations['con'].iloc[7,] = "Mono"
stations['con'].iloc[8,] = "Multi"
stations['con'].iloc[9,] = "Mono"
stations['con'].iloc[10,] = "Multi"
stations['con'].iloc[11,] = "Multi"
stations['con'].iloc[12,] = "Multi"
stations['con'].iloc[13,] = "Multi"
stations['con'].iloc[14,] = "Multi"
stations['con'].iloc[15,] = "Multi"
stations['con'].iloc[16,] = "Multi"
stations['con'].iloc[17,] = "Multi"
stations['con'].iloc[18,] = "Multi"
stations['con'].iloc[19,] = "Multi"
stations['con'].iloc[20,] = "Mono"
stations['con'].iloc[21,] = "Mono"
stations['con'].iloc[22,] = "Multi"
stations['con'].iloc[23,] = "Mono"
stations['con'].iloc[24,] = "Multi"
stations['con'].iloc[25,] = "Mono"
stations['con'].iloc[26,] = "Mono"
stations['con'].iloc[27,] = "Mono"
stations['con'].iloc[28,] = "Multi"
stations['con'].iloc[29,] = "Multi"
stations['con'].iloc[30,] = "Multi"
stations['con'].iloc[31,] = "Mono"
stations['con'].iloc[32,] = "Mono"
stations['con'].iloc[33,] = "Mono"
stations['con'].iloc[34,] = "Multi"
stations['con'].iloc[35,] = "Mono"
stations['con'].iloc[36,] = "Multi"
stations['con'].iloc[37,] = "Multi"
stations['con'].iloc[38,] = "Multi"
stations['con'].iloc[39,] = "Multi"
stations['con'].iloc[40,] = "Multi"
# Out:
# /tmp/ipykernel_2515/2512871001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations['con'].iloc[0,] = "Multi"

# %%
# Loading track shapefile
track = el_track_raw.copy()
track.head()    
track.plot()

print(track.head())
# Out:
#    OBJECTID     ROUTEDESC    BRANCHDESC DIRECTDESC  \
# 0         1  Network Rail  Western Spur  Eastbound
# 1         2  Network Rail  Western Spur  Eastbound
# 2         3  Network Rail  Western Spur  Eastbound
# 3         4  Network Rail  Western Spur  Eastbound
# 4         5  Network Rail  Western Spur  Eastbound
#
#                                             geometry
# 0  LINESTRING (521936.314 182273.252, 521935.366 ...
# 1  LINESTRING (521959.564 182241.351, 521958.663 ...
# 2  LINESTRING (521970.633 182264.311, 521969.731 ...
# 3  LINESTRING (521961.418 182303.518, 521960.645 ...
# 4  LINESTRING (521953.921 182240.761, 521952.973 ...

# %% [markdown]
# ### 1.3 Loading London borough data

# %%
borough = London_ex_raw.copy()
borough.head()   
borough.plot()

print(borough.info(verbose=True))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        33 non-null     object
#  1   GSS_CODE    33 non-null     object
#  2   HECTARES    33 non-null     float64
#  3   NONLD_AREA  33 non-null     float64
#  4   ONS_INNER   33 non-null     object
#  5   SUB_2009    0 non-null      object
#  6   SUB_2006    0 non-null      object
#  7   geometry    33 non-null     geometry
# dtypes: float64(2), geometry(1), object(5)
# memory usage: 2.2+ KB
# None

# %% [markdown]
# ## 2. Cleaning data

# %% [markdown]
# ### Introduction
#
# In this section, we focus on reprojection and cleaning the airbnbn dataset. We firstly detect the crs of three geographic files and making sure they are the same. Then we detect and drop the NaNs and Nulls values. Lastly we change the 'price' column from 'string' to 'float' so that we can calculate later.

# %% [markdown]
# ### 2.1 Reprojection

# %%
# Detecting crs
print(borough.crs)
print(stations.crs)
print(track.crs)
# Out:
# PROJCS["OSGB36 / British National Grid",GEOGCS["OSGB36",DATUM["Ordnance_Survey_of_Great_Britain_1936",SPHEROID["Airy 1830",6377563.396,299.3249646,AUTHORITY["EPSG","7001"]],AUTHORITY["EPSG","6277"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",49],PARAMETER["central_meridian",-2],PARAMETER["scale_factor",0.999601272],PARAMETER["false_easting",400000],PARAMETER["false_northing",-100000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# epsg:27700
# epsg:27700

# %%
# Reproject them to EPSG 27700 (British National Grid)
borough= borough.to_crs('epsg:27700')
stations = stations.to_crs('epsg:27700')
track = track.to_crs('epsg:27700')

print(borough.crs)
print(stations.crs)
print(track.crs)
# Out:
# epsg:27700
# epsg:27700
# epsg:27700

# %% [markdown]
# ### 2.2 Cleaning Airbnb dataset

# %% [markdown]
# #### 2.2.1 Dealing with NaNs and Nulls

# %%
airbnb_2020[airbnb_2020.price.isna()]
# Out:
#                id                            listing_url         scrape_id  \
# 3558    3138549.0   https://www.airbnb.com/rooms/3138549  20200824024753.0
# 29989  21549106.0  https://www.airbnb.com/rooms/21549106    20200824024753
#
#       last_scraped                                           name  \
# 3558    2020-08-26             Heart of City of London/Shoreditch
# 29989   2020-08-27  Richmond Luxury, High ceilings & Free Parking
#
#                                              description  \
# 3558   Our lovely flat is in a newly designed buildin...
# 29989  Welcome to my Richmond (not East Twickenham) b...
#
#                                    neighborhood_overview  \
# 3558   Old Street is in the heart of Shoreditch, with...
# 29989  Richmond is famous for its Royal parks & impre...
#
#                                              picture_url      host_id  \
# 3558   https://a0.muscache.com/pictures/ed787e5d-730c...    4968944.0
# 29989  https://a0.muscache.com/pictures/355d8a17-8d9e...  123942428.0
#
#                                           host_url  ...  \
# 3558     https://www.airbnb.com/users/show/4968944  ...
# 29989  https://www.airbnb.com/users/show/123942428  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 3558                          NaN                    NaN                 NaN
# 29989                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 3558      NaN              NaN                            NaN
# 29989     NaN              NaN                            NaN
#
#       calculated_host_listings_count_entire_homes  \
# 3558                                          NaN
# 29989                                         NaN
#
#       calculated_host_listings_count_private_rooms  \
# 3558                                           NaN
# 29989                                          NaN
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 3558                                          NaN               NaN
# 29989                                         NaN               NaN
#
# [2 rows x 74 columns]

# %%
airbnb_2022[airbnb_2022.price.isna()]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, source, name, description, neighborhood_overview, picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, license, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month]
# Index: []
#
# [0 rows x 75 columns]

# %%
airbnb_2020[~(airbnb_2020.price.str.startswith('$', na=False))]
# Out:
#                id                            listing_url         scrape_id  \
# 3558    3138549.0   https://www.airbnb.com/rooms/3138549  20200824024753.0
# 3559          NaN                                    NaN               NaN
# 29989  21549106.0  https://www.airbnb.com/rooms/21549106    20200824024753
# 29990         NaN                         within an hour              100%
#
#       last_scraped                                           name  \
# 3558    2020-08-26             Heart of City of London/Shoreditch
# 3559           NaN                                              f
# 29989   2020-08-27  Richmond Luxury, High ceilings & Free Parking
# 29990          74%                                              f
#
#                                              description  \
# 3558   Our lovely flat is in a newly designed buildin...
# 3559   https://a0.muscache.com/im/pictures/user/1c171...
# 29989  Welcome to my Richmond (not East Twickenham) b...
# 29990  https://a0.muscache.com/im/pictures/user/19315...
#
#                                    neighborhood_overview  \
# 3558   Old Street is in the heart of Shoreditch, with...
# 3559   https://a0.muscache.com/im/pictures/user/1c171...
# 29989  Richmond is famous for its Royal parks & impre...
# 29990  https://a0.muscache.com/im/pictures/user/19315...
#
#                                              picture_url      host_id  \
# 3558   https://a0.muscache.com/pictures/ed787e5d-730c...    4968944.0
# 3559                                          Shoreditch          1.0
# 29989  https://a0.muscache.com/pictures/355d8a17-8d9e...  123942428.0
# 29990                                           Richmond          1.0
#
#                                           host_url  ...  \
# 3558     https://www.airbnb.com/users/show/4968944  ...
# 3559                                           1.0  ...
# 29989  https://www.airbnb.com/users/show/123942428  ...
# 29990                                          1.0  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 3558                          NaN                    NaN                 NaN
# 3559                          NaN                    NaN                 NaN
# 29989                         NaN                    NaN                 NaN
# 29990                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 3558      NaN              NaN                            NaN
# 3559      NaN              NaN                            NaN
# 29989     NaN              NaN                            NaN
# 29990     NaN              NaN                            NaN
#
#       calculated_host_listings_count_entire_homes  \
# 3558                                          NaN
# 3559                                          NaN
# 29989                                         NaN
# 29990                                         NaN
#
#       calculated_host_listings_count_private_rooms  \
# 3558                                           NaN
# 3559                                           NaN
# 29989                                          NaN
# 29990                                          NaN
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 3558                                          NaN               NaN
# 3559                                          NaN               NaN
# 29989                                         NaN               NaN
# 29990                                         NaN               NaN
#
# [4 rows x 74 columns]

# %%
airbnb_2022[~(airbnb_2022.price.str.startswith('$', na=False))]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, source, name, description, neighborhood_overview, picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, license, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month]
# Index: []
#
# [0 rows x 75 columns]

# %%
airbnb_2020[airbnb_2020.id.isna()][['id','listing_url','name','description','host_id','host_name','price']]
# Out:
#        id     listing_url name  \
# 3559  NaN             NaN    f
# 29990 NaN  within an hour    f
#
#                                              description  host_id  \
# 3559   https://a0.muscache.com/im/pictures/user/1c171...      1.0
# 29990  https://a0.muscache.com/im/pictures/user/19315...      1.0
#
#                                                host_name price
# 3559   ['email', 'phone', 'reviews', 'jumio', 'govern...     0
# 29990  ['email', 'phone', 'facebook', 'reviews', 'jum...    10

# %%
airbnb_2022[airbnb_2022.id.isna()][['id','listing_url','name','description','host_id','host_name','price']]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, name, description, host_id, host_name, price]
# Index: []

# %%
airbnb_2020[airbnb_2020.neighbourhood_cleansed.isna()]
# Out:
#                id                            listing_url         scrape_id  \
# 3558    3138549.0   https://www.airbnb.com/rooms/3138549  20200824024753.0
# 29989  21549106.0  https://www.airbnb.com/rooms/21549106    20200824024753
#
#       last_scraped                                           name  \
# 3558    2020-08-26             Heart of City of London/Shoreditch
# 29989   2020-08-27  Richmond Luxury, High ceilings & Free Parking
#
#                                              description  \
# 3558   Our lovely flat is in a newly designed buildin...
# 29989  Welcome to my Richmond (not East Twickenham) b...
#
#                                    neighborhood_overview  \
# 3558   Old Street is in the heart of Shoreditch, with...
# 29989  Richmond is famous for its Royal parks & impre...
#
#                                              picture_url      host_id  \
# 3558   https://a0.muscache.com/pictures/ed787e5d-730c...    4968944.0
# 29989  https://a0.muscache.com/pictures/355d8a17-8d9e...  123942428.0
#
#                                           host_url  ...  \
# 3558     https://www.airbnb.com/users/show/4968944  ...
# 29989  https://www.airbnb.com/users/show/123942428  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 3558                          NaN                    NaN                 NaN
# 29989                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 3558      NaN              NaN                            NaN
# 29989     NaN              NaN                            NaN
#
#       calculated_host_listings_count_entire_homes  \
# 3558                                          NaN
# 29989                                         NaN
#
#       calculated_host_listings_count_private_rooms  \
# 3558                                           NaN
# 29989                                          NaN
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 3558                                          NaN               NaN
# 29989                                         NaN               NaN
#
# [2 rows x 74 columns]

# %%
airbnb_2022[airbnb_2022.neighbourhood_cleansed.isna()]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, source, name, description, neighborhood_overview, picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, license, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month]
# Index: []
#
# [0 rows x 75 columns]

# %%
# Dropping the NaNs and Nulls in column 'id', 'price', 'neighbourhood_cleansed'
airbnb_2020.drop(airbnb_2020[airbnb_2020.id.isna()].index.array, axis=0, inplace=True)
airbnb_2022.drop(airbnb_2022[airbnb_2022.id.isna()].index.array, axis=0, inplace=True)

airbnb_2020.drop(airbnb_2020[airbnb_2020.price.isna()].index.array, axis=0, inplace=True)
airbnb_2022.drop(airbnb_2022[airbnb_2022.price.isna()].index.array, axis=0, inplace=True)

airbnb_2020.drop(airbnb_2020[airbnb_2020.neighbourhood_cleansed.isna()].index.array, axis=0, inplace=True)
airbnb_2022.drop(airbnb_2022[airbnb_2022.neighbourhood_cleansed.isna()].index.array, axis=0, inplace=True)

# %% [markdown]
# #### 2.2.2 Dealing with srtings (price)

# %%
money = ['price']
airbnb_2020.sample(5, random_state=42)[money]
# Out:
#          price
# 66121   $89.00
# 58701  $125.00
# 53195   $27.00
# 64796  $169.00
# 46074   $70.00

# %%
# Convering price for Airbnb2020 dataset
for m in money:
    print(f"Converting {m}")
    airbnb_2020[m] = airbnb_2020[m].str.replace('$','', regex=False).str.replace(',','', regex=False).astype('float')
# Out:
# Converting price

# %%
# Convering price for Airbnb2022 dataset
for m in money:
    print(f"Converting {m}")
    airbnb_2022[m] = airbnb_2022[m].str.replace('$','', regex=False).str.replace(',','', regex=False).astype('float')
# Out:
# Converting price

# %%
# Check
airbnb_2020.sample(5, random_state=42)[money]
# Out:
#        price
# 66121   89.0
# 58701  125.0
# 53195   27.0
# 64796  169.0
# 46074   70.0

# %%
# Check
airbnb_2022.sample(5, random_state=42)[money]
# Out:
#        price
# 26643   22.0
# 15713  450.0
# 67606  175.0
# 40703  214.0
# 625     50.0

# %% [markdown]
# ## 3. Manipulating Data

# %% [markdown]
# ### Introduction
#
# In this section, we aim to manipulate the long-term and short-term (aibnb) dataset to prepare the mapping in the next section:
#
# For short-term (airbnb) data, we firstly group the price by boroughs and calculate the median price. Secondly we merge the two airbnb dataset into one and calculate the increasing rate during the two years. In the end, we choose the boroughs through which the Elizabeth Line passes.
#
# For long-term data, it is collected on a borough basis so we don't need to group by like airbnb data. What we deal with it just calculate the increasing rate and choose the boroughs that Elizabeth Line passes.

# %% [markdown]
# ### 3.1 Short-term rental data (Airbnb data)

# %% [markdown]
# #### 3.1.1 Calculating global increasing rate

# %%
# Calculating the global increasing rate
year2020 = airbnb_2020['price'].median()
year2022 = airbnb_2022['price'].median()

global_airbnb = ((year2022-year2020)/(year2020))*100
global_airbnb
# Out:
# 26.582278481012654

# %% [markdown]
# #### 3.1.2 Calculating increasing rate by boroughs

# %%
# Grouping airbnb data by boroughs and each calculating the median price of each groups
airbnb_2020_grouped = airbnb_2020.groupby('neighbourhood_cleansed')['price'].median()
airbnb_2022_grouped = airbnb_2022.groupby('neighbourhood_cleansed')['price'].median()

# Converting series to dataframe, and renaming column name in order to avoid duplication when combining two dataset
airbnb_2020_grouped = airbnb_2020_grouped.to_frame()
airbnb_2020_grouped = airbnb_2020_grouped.rename(columns = {"price": "price2020"})
airbnb_2022_grouped = airbnb_2022_grouped.to_frame()
airbnb_2022_grouped = airbnb_2022_grouped.rename(columns = {"price": "price2022"})

# Combining two dataset
airbnb = pd.concat([airbnb_2020_grouped,airbnb_2022_grouped],axis=1)

# Renaming the borough column to make the subsequent merge easier
airbnb.rename(columns = {"neighbourhood_cleansed": "GSS_CODE"})
# Out:
#                         price2020  price2022
# neighbourhood_cleansed
# Barking and Dagenham         43.0       60.0
# Barnet                       55.0       80.0
# Bexley                       39.0       60.0
# Brent                        61.0       85.0
# Bromley                      50.0       70.0
# Camden                       94.0      125.0
# City of London              125.0      196.0
# Croydon                      40.0       60.0
# Ealing                       50.0       70.0
# Enfield                      50.0       65.0
# Greenwich                    61.0       80.0
# Hackney                      70.0       86.0
# Hammersmith and Fulham       90.0      112.5
# Haringey                     52.0       70.0
# Harrow                       45.0       75.0
# Havering                     49.0       70.0
# Hillingdon                   45.0       68.0
# Hounslow                     58.0       81.0
# Islington                    84.0       99.0
# Kensington and Chelsea      128.0      186.0
# Kingston upon Thames         50.0       78.0
# Lambeth                      70.0       87.0
# Lewisham                     50.0       65.5
# Merton                       65.0       85.0
# Newham                       51.0       76.0
# Redbridge                    48.0       62.0
# Richmond upon Thames         84.0      100.0
# Southwark                    75.0       95.0
# Sutton                       45.0       60.0
# Tower Hamlets                68.0       85.0
# Waltham Forest               50.0       70.0
# Wandsworth                   80.0       99.0
# Westminster                 122.0      179.0

# %%
# Calculating the increase rate 
increase_rate_airbnb = ((airbnb['price2022']-airbnb['price2020'])/(airbnb['price2020']))*100

# Adding as a new column
s = pd.Series(increase_rate_airbnb)
airbnb.insert(2, 'increase_rate_airbnb', s)

# Converting data to percentage
# airbnb[u'increase_rate_airbnb'] = airbnb[u'increase_rate_airbnb'].apply(lambda x: format(x, '.0%'))
airbnb
# Out:
#                         price2020  price2022  increase_rate_airbnb
# neighbourhood_cleansed
# Barking and Dagenham         43.0       60.0             39.534884
# Barnet                       55.0       80.0             45.454545
# Bexley                       39.0       60.0             53.846154
# Brent                        61.0       85.0             39.344262
# Bromley                      50.0       70.0             40.000000
# Camden                       94.0      125.0             32.978723
# City of London              125.0      196.0             56.800000
# Croydon                      40.0       60.0             50.000000
# Ealing                       50.0       70.0             40.000000
# Enfield                      50.0       65.0             30.000000
# Greenwich                    61.0       80.0             31.147541
# Hackney                      70.0       86.0             22.857143
# Hammersmith and Fulham       90.0      112.5             25.000000
# Haringey                     52.0       70.0             34.615385
# Harrow                       45.0       75.0             66.666667
# Havering                     49.0       70.0             42.857143
# Hillingdon                   45.0       68.0             51.111111
# Hounslow                     58.0       81.0             39.655172
# Islington                    84.0       99.0             17.857143
# Kensington and Chelsea      128.0      186.0             45.312500
# Kingston upon Thames         50.0       78.0             56.000000
# Lambeth                      70.0       87.0             24.285714
# Lewisham                     50.0       65.5             31.000000
# Merton                       65.0       85.0             30.769231
# Newham                       51.0       76.0             49.019608
# Redbridge                    48.0       62.0             29.166667
# Richmond upon Thames         84.0      100.0             19.047619
# Southwark                    75.0       95.0             26.666667
# Sutton                       45.0       60.0             33.333333
# Tower Hamlets                68.0       85.0             25.000000
# Waltham Forest               50.0       70.0             40.000000
# Wandsworth                   80.0       99.0             23.750000
# Westminster                 122.0      179.0             46.721311

# %%
airbnb = airbnb.reset_index()
airbnb = airbnb.rename(columns={'neighbourhood_cleansed':'NAME'})

# %% [markdown]
# #### 3.1.3 Choosing the boroughs through which the Elizabeth Line passes

# %%
# Choose the boroughs through which the Elizabeth Line passes
list_one=['Westminster','Hillingdon','Ealing','Hammersmith and Fulham','Kensington and Chelsea','Camden','Islington','City of London','Tower Hamlets','Newham','Greenwich','Redbridge','Barking and Dagenham','Havering']
airbnb_choose = airbnb[(airbnb['NAME'].isin(list_one))]
airbnb_choose
# Out:
#                       NAME  price2020  price2022  increase_rate_airbnb
# 0     Barking and Dagenham       43.0       60.0             39.534884
# 5                   Camden       94.0      125.0             32.978723
# 6           City of London      125.0      196.0             56.800000
# 8                   Ealing       50.0       70.0             40.000000
# 10               Greenwich       61.0       80.0             31.147541
# 12  Hammersmith and Fulham       90.0      112.5             25.000000
# 15                Havering       49.0       70.0             42.857143
# 16              Hillingdon       45.0       68.0             51.111111
# 18               Islington       84.0       99.0             17.857143
# 19  Kensington and Chelsea      128.0      186.0             45.312500
# 24                  Newham       51.0       76.0             49.019608
# 25               Redbridge       48.0       62.0             29.166667
# 29           Tower Hamlets       68.0       85.0             25.000000
# 32             Westminster      122.0      179.0             46.721311

# %% [markdown]
# ### 3.2 Long-term rental data

# %% [markdown]
# #### 3.2.1 Calculating global increasing rate

# %%
# Calculating the global increasing rate
year2020_long = longterm_rental['median_2020'].median()
year2022_long = longterm_rental['median_2022'].median()

global_increase_rate_longterm = ((year2022_long-year2020_long)/(year2020_long))*100
global_increase_rate_longterm
# Out:
# 4.145077720207254

# %% [markdown]
# #### 3.2.2 Calculating increasing rate by boroughs

# %%
# Calculating the increase rate 
increase_rate_longterm = ((longterm_rental['median_2022']-longterm_rental['median_2020'])/(longterm_rental['median_2020']))*100

# Adding as a new column
s = pd.Series(increase_rate_longterm)
longterm_rental.insert(4, 'increase_rate_longterm', s)

# Converting data to percentage
#rent_price_merge[u'increase_rate_rent'] = rent_price_merge[u'increase_rate_rent'].apply(lambda x: format(x, '.2%'))

longterm_rental
# Out:
#               borough_name      code   median_2020  median_2022  \
# 0     Barking and Dagenham  E09000002         1104         1150
# 1                   Barnet  E09000003         1532         1416
# 2                   Bexley  E09000004          990         1151
# 3                    Brent  E09000005         1339         1352
# 4                  Bromley  E09000006         1183         1291
# 5                   Camden  E09000007         1921         2217
# 6           City of London  E09000001         1998         1851
# 7                  Croydon  E09000008         1128         1171
# 8                   Ealing  E09000009         1458         1448
# 9                  Enfield  E09000010         1294         1242
# 10               Greenwich  E09000011         1343         1278
# 11                 Hackney  E09000012         1955         1950
# 12  Hammersmith and Fulham  E09000013         1928         2200
# 13                Haringey  E09000014         1468         1433
# 14                  Harrow  E09000015         1241         1265
# 15                Havering  E09000016         1051         1127
# 16              Hillingdon  E09000017         1147         1165
# 17                Hounslow  E09000018         1267         1258
# 18               Islington  E09000019         2083         1800
# 19  Kensington and Chelsea  E09000020         3474         2919
# 20    Kingston upon Thames  E09000021         1284         1356
# 21                 Lambeth  E09000022         1738         1707
# 22                Lewisham  E09000023         1299         1374
# 23                  Merton  E09000024         1487         1513
# 24                  Newham  E09000025         1351         1407
# 25               Redbridge  E09000026         1226         1231
# 26    Richmond upon Thames  E09000027         1860         1752
# 27               Southwark  E09000028         1585         1713
# 28                  Sutton  E09000029         1130         1364
# 29           Tower Hamlets  E09000030         1694         1723
# 30          Waltham Forest  E09000031         1246         1256
# 31              Wandsworth  E09000032         1890         1829
# 32             Westminster  E09000033         2998         2646
#
#     increase_rate_longterm
# 0                 4.166667
# 1                -7.571802
# 2                16.262626
# 3                 0.970874
# 4                 9.129332
# 5                15.408641
# 6                -7.357357
# 7                 3.812057
# 8                -0.685871
# 9                -4.018547
# 10               -4.839911
# 11               -0.255754
# 12               14.107884
# 13               -2.384196
# 14                1.933924
# 15                7.231208
# 16                1.569311
# 17               -0.710339
# 18              -13.586174
# 19              -15.975820
# 20                5.607477
# 21               -1.783659
# 22                5.773672
# 23                1.748487
# 24                4.145078
# 25                0.407830
# 26               -5.806452
# 27                8.075710
# 28               20.707965
# 29                1.711924
# 30                0.802568
# 31               -3.227513
# 32              -11.741161

# %%
# Renaming column 'borough_name' to 'NAME' in order to merge with borough dataset
longterm_rental = longterm_rental.rename(columns={'borough_name':'NAME'})

# %% [markdown]
# #### 3.2.3 Choosing the boroughs through which the Elizabeth Line passes

# %%
# Choose the boroughs through which the Elizabeth Line passes
list_one=['Westminster','Hillingdon','Ealing','Hammersmith and Fulham','Kensington and Chelsea','Camden','Islington','City of London','Tower Hamlets','Newham','Greenwich','Redbridge','Barking and Dagenham','Havering']
longterm_choose = longterm_rental[(longterm_rental['NAME'].isin(list_one))]
#a=airbnb[(df['table'].isin(list_one))]
longterm_choose
# Out:
#                       NAME      code   median_2020  median_2022  \
# 0     Barking and Dagenham  E09000002         1104         1150
# 5                   Camden  E09000007         1921         2217
# 6           City of London  E09000001         1998         1851
# 8                   Ealing  E09000009         1458         1448
# 10               Greenwich  E09000011         1343         1278
# 12  Hammersmith and Fulham  E09000013         1928         2200
# 15                Havering  E09000016         1051         1127
# 16              Hillingdon  E09000017         1147         1165
# 18               Islington  E09000019         2083         1800
# 19  Kensington and Chelsea  E09000020         3474         2919
# 24                  Newham  E09000025         1351         1407
# 25               Redbridge  E09000026         1226         1231
# 29           Tower Hamlets  E09000030         1694         1723
# 32             Westminster  E09000033         2998         2646
#
#     increase_rate_longterm
# 0                 4.166667
# 5                15.408641
# 6                -7.357357
# 8                -0.685871
# 10               -4.839911
# 12               14.107884
# 15                7.231208
# 16                1.569311
# 18              -13.586174
# 19              -15.975820
# 24                4.145078
# 25                0.407830
# 29                1.711924
# 32              -11.741161

# %% [markdown]
# ## 4. Mapping

# %% [markdown]
# ### Introduction
#
# In this section, we plot two maps to show the price change of long-term and short-term rental market. We merge the london borough document with the value document firstly, and then plot it with the track and station documents at the same time. Then we set the colour of boroughs depending on the value of increasing rate and add the title and label. In the end, the syncretic maps have been done.

# %% [markdown]
# ### 4.1 Short-term (Airbnb)

# %%
# Combining price and borough
# Mark the value of the area that the Elizabethan line does not pass through as 0
airbnb_merge = pd.merge(borough, airbnb_choose, on='NAME',how='left')
airbnb_merge = airbnb_merge.replace(np.nan,0)
airbnb_merge
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# 12                Lewisham  E09000023   3531.706      16.795         T
# 13               Greenwich  E09000011   5044.190     310.785         F
# 14                  Bexley  E09000004   6428.649     370.619         F
# 15                 Enfield  E09000010   8220.025       0.000         F
# 16          Waltham Forest  E09000031   3880.793       0.000         F
# 17               Redbridge  E09000026   5644.225       2.300         F
# 18                  Sutton  E09000029   4384.698       0.000         F
# 19    Richmond upon Thames  E09000027   5876.111     135.443         F
# 20                  Merton  E09000024   3762.466       0.000         F
# 21              Wandsworth  E09000032   3522.022      95.600         T
# 22  Hammersmith and Fulham  E09000013   1715.409      75.648         T
# 23  Kensington and Chelsea  E09000020   1238.379      25.994         T
# 24             Westminster  E09000033   2203.005      54.308         T
# 25                  Camden  E09000007   2178.932       0.000         T
# 26           Tower Hamlets  E09000030   2157.501     179.707         T
# 27               Islington  E09000019   1485.664       0.000         T
# 28                 Hackney  E09000012   1904.902       0.000         T
# 29                Haringey  E09000014   2959.837       0.000         T
# 30                  Newham  E09000025   3857.806     237.637         T
# 31    Barking and Dagenham  E09000002   3779.934     169.150         F
# 32          City of London  E09000001    314.942      24.546         T
#
#     SUB_2009  SUB_2006                                           geometry  \
# 0          0         0  POLYGON ((516401.600 160201.800, 516407.300 16...
# 1          0         0  POLYGON ((535009.200 159504.700, 535005.500 15...
# 2          0         0  POLYGON ((540373.600 157530.400, 540361.200 15...
# 3          0         0  POLYGON ((521975.800 178100.000, 521967.700 17...
# 4          0         0  POLYGON ((510253.500 182881.600, 510249.900 18...
# 5          0         0  POLYGON ((549893.900 181459.800, 549894.600 18...
# 6          0         0  POLYGON ((510599.800 191689.500, 510615.200 19...
# 7          0         0  POLYGON ((510599.800 191689.500, 510660.000 19...
# 8          0         0  POLYGON ((525201.000 182512.600, 525181.500 18...
# 9          0         0  POLYGON ((524579.900 198355.200, 524594.300 19...
# 10         0         0  POLYGON ((530046.800 177893.400, 530048.400 17...
# 11         0         0  POLYGON ((531335.600 180529.500, 531337.700 18...
# 12         0         0  POLYGON ((536691.000 178958.600, 536691.900 17...
# 13         0         0  MULTIPOLYGON (((537238.700 178137.700, 537242....
# 14         0         0  POLYGON ((547226.200 181299.300, 547320.900 18...
# 15         0         0  POLYGON ((531023.500 200933.600, 531039.900 20...
# 16         0         0  POLYGON ((539923.100 191863.100, 539928.100 19...
# 17         0         0  POLYGON ((543595.500 184832.800, 543577.100 18...
# 18         0         0  POLYGON ((528552.300 159658.100, 528399.700 15...
# 19         0         0  POLYGON ((516677.500 175383.800, 516678.600 17...
# 20         0         0  POLYGON ((529906.200 167417.300, 529902.200 16...
# 21         0         0  POLYGON ((523489.600 176224.800, 523500.600 17...
# 22         0         0  POLYGON ((521975.800 178100.000, 521973.000 17...
# 23         0         0  POLYGON ((526219.700 176948.000, 526208.800 17...
# 24         0         0  POLYGON ((528549.500 177903.800, 528542.600 17...
# 25         0         0  POLYGON ((528840.200 187217.800, 528834.600 18...
# 26         0         0  POLYGON ((533387.600 180516.400, 533389.800 18...
# 27         0         0  POLYGON ((529153.600 185861.400, 529144.800 18...
# 28         0         0  POLYGON ((531928.400 187801.500, 531935.700 18...
# 29         0         0  POLYGON ((531928.400 187801.500, 531919.200 18...
# 30         0         0  MULTIPOLYGON (((544065.000 183254.100, 544062....
# 31         0         0  MULTIPOLYGON (((543905.400 183199.100, 543905....
# 32         0         0  POLYGON ((531145.100 180782.100, 531143.800 18...
#
#     price2020  price2022  increase_rate_airbnb
# 0         0.0        0.0              0.000000
# 1         0.0        0.0              0.000000
# 2         0.0        0.0              0.000000
# 3         0.0        0.0              0.000000
# 4        50.0       70.0             40.000000
# 5        49.0       70.0             42.857143
# 6        45.0       68.0             51.111111
# 7         0.0        0.0              0.000000
# 8         0.0        0.0              0.000000
# 9         0.0        0.0              0.000000
# 10        0.0        0.0              0.000000
# 11        0.0        0.0              0.000000
# 12        0.0        0.0              0.000000
# 13       61.0       80.0             31.147541
# 14        0.0        0.0              0.000000
# 15        0.0        0.0              0.000000
# 16        0.0        0.0              0.000000
# 17       48.0       62.0             29.166667
# 18        0.0        0.0              0.000000
# 19        0.0        0.0              0.000000
# 20        0.0        0.0              0.000000
# 21        0.0        0.0              0.000000
# 22       90.0      112.5             25.000000
# 23      128.0      186.0             45.312500
# 24      122.0      179.0             46.721311
# 25       94.0      125.0             32.978723
# 26       68.0       85.0             25.000000
# 27       84.0       99.0             17.857143
# 28        0.0        0.0              0.000000
# 29        0.0        0.0              0.000000
# 30       51.0       76.0             49.019608
# 31       43.0       60.0             39.534884
# 32      125.0      196.0             56.800000

# %% [markdown]
# Global increasing rate of Airbnb between 2020 and 2022 is 26.6%.
#
# In the plot, the blue colours indicate a higher increasing rate than global and the grey colours indicates a lower increasing rate than global.

# %%
#setup the font
tfont = {'fontname':'Liberation Sans Narrow', 'weight':'bold'}
afont = {'fontname':'Liberation Sans Narrow', 'weight':'light'}

# Airbnb increasing rate plot

fig, ax = plt.subplots(1,1, figsize=(12,9))

# create discrete colormap
# https://xkcd.com/color/rgb/ very light pink
cmap = colors.ListedColormap(['gainsboro','thistle','plum','orchid','purple','indigo'])
bounds = [0,0.0001,14.6,26.6,38.6,50.6,62.6]
norm = colors.BoundaryNorm(bounds, cmap.N)


airbnb_merge.plot(ax=ax,figsize=(12,8), marker='*', markersize=0.25,  
         column='increase_rate_airbnb',cmap=cmap, legend=True, norm=norm,edgecolor='white',legend_kwds={'shrink': 0.8})
         
track.plot(ax=ax, edgecolor='steelblue', linewidth=2.5)
stations.plot(ax=ax, column='STATION_NA', color='steelblue')

# Set the x and y limits
ax.set_xlim(501000,563000)
ax.set_ylim(155000,202000)

#set a legend
mylabels= ['Elizabeth Line', 'Stations']
ax.legend(track, loc='lower right', frameon=False, labels=mylabels)

plt.savefig("Airbnb.png", bbox_inches = 'tight')
plt.axis('off')
plt.suptitle("Rental price increasing rate along Elizabeth line between 2020 and 2022", y=0.9, size=24, **tfont)
plt.title("Short-term (Airbnb), by borough (%)", loc='left', size=16,**afont)
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# /tmp/ipykernel_2515/1535166153.py:28: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend(track, loc='lower right', frameon=False, labels=mylabels)
# Text(0.0, 1.0, 'Short-term (Airbnb), by borough (%)')

# %% [markdown]
# ### 4.2 Long-term

# %%
# Combining price and borough
# Mark the value of the area that the Elizabethan line does not pass through as 0
longterm_merge=pd.merge(borough, longterm_choose, on='NAME',how='left')
longterm_merge=longterm_merge.replace(np.nan,0)
longterm_merge
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# 12                Lewisham  E09000023   3531.706      16.795         T
# 13               Greenwich  E09000011   5044.190     310.785         F
# 14                  Bexley  E09000004   6428.649     370.619         F
# 15                 Enfield  E09000010   8220.025       0.000         F
# 16          Waltham Forest  E09000031   3880.793       0.000         F
# 17               Redbridge  E09000026   5644.225       2.300         F
# 18                  Sutton  E09000029   4384.698       0.000         F
# 19    Richmond upon Thames  E09000027   5876.111     135.443         F
# 20                  Merton  E09000024   3762.466       0.000         F
# 21              Wandsworth  E09000032   3522.022      95.600         T
# 22  Hammersmith and Fulham  E09000013   1715.409      75.648         T
# 23  Kensington and Chelsea  E09000020   1238.379      25.994         T
# 24             Westminster  E09000033   2203.005      54.308         T
# 25                  Camden  E09000007   2178.932       0.000         T
# 26           Tower Hamlets  E09000030   2157.501     179.707         T
# 27               Islington  E09000019   1485.664       0.000         T
# 28                 Hackney  E09000012   1904.902       0.000         T
# 29                Haringey  E09000014   2959.837       0.000         T
# 30                  Newham  E09000025   3857.806     237.637         T
# 31    Barking and Dagenham  E09000002   3779.934     169.150         F
# 32          City of London  E09000001    314.942      24.546         T
#
#     SUB_2009  SUB_2006                                           geometry  \
# 0          0         0  POLYGON ((516401.600 160201.800, 516407.300 16...
# 1          0         0  POLYGON ((535009.200 159504.700, 535005.500 15...
# 2          0         0  POLYGON ((540373.600 157530.400, 540361.200 15...
# 3          0         0  POLYGON ((521975.800 178100.000, 521967.700 17...
# 4          0         0  POLYGON ((510253.500 182881.600, 510249.900 18...
# 5          0         0  POLYGON ((549893.900 181459.800, 549894.600 18...
# 6          0         0  POLYGON ((510599.800 191689.500, 510615.200 19...
# 7          0         0  POLYGON ((510599.800 191689.500, 510660.000 19...
# 8          0         0  POLYGON ((525201.000 182512.600, 525181.500 18...
# 9          0         0  POLYGON ((524579.900 198355.200, 524594.300 19...
# 10         0         0  POLYGON ((530046.800 177893.400, 530048.400 17...
# 11         0         0  POLYGON ((531335.600 180529.500, 531337.700 18...
# 12         0         0  POLYGON ((536691.000 178958.600, 536691.900 17...
# 13         0         0  MULTIPOLYGON (((537238.700 178137.700, 537242....
# 14         0         0  POLYGON ((547226.200 181299.300, 547320.900 18...
# 15         0         0  POLYGON ((531023.500 200933.600, 531039.900 20...
# 16         0         0  POLYGON ((539923.100 191863.100, 539928.100 19...
# 17         0         0  POLYGON ((543595.500 184832.800, 543577.100 18...
# 18         0         0  POLYGON ((528552.300 159658.100, 528399.700 15...
# 19         0         0  POLYGON ((516677.500 175383.800, 516678.600 17...
# 20         0         0  POLYGON ((529906.200 167417.300, 529902.200 16...
# 21         0         0  POLYGON ((523489.600 176224.800, 523500.600 17...
# 22         0         0  POLYGON ((521975.800 178100.000, 521973.000 17...
# 23         0         0  POLYGON ((526219.700 176948.000, 526208.800 17...
# 24         0         0  POLYGON ((528549.500 177903.800, 528542.600 17...
# 25         0         0  POLYGON ((528840.200 187217.800, 528834.600 18...
# 26         0         0  POLYGON ((533387.600 180516.400, 533389.800 18...
# 27         0         0  POLYGON ((529153.600 185861.400, 529144.800 18...
# 28         0         0  POLYGON ((531928.400 187801.500, 531935.700 18...
# 29         0         0  POLYGON ((531928.400 187801.500, 531919.200 18...
# 30         0         0  MULTIPOLYGON (((544065.000 183254.100, 544062....
# 31         0         0  MULTIPOLYGON (((543905.400 183199.100, 543905....
# 32         0         0  POLYGON ((531145.100 180782.100, 531143.800 18...
#
#         code   median_2020  median_2022  increase_rate_longterm
# 0           0          0.0          0.0                0.000000
# 1           0          0.0          0.0                0.000000
# 2           0          0.0          0.0                0.000000
# 3           0          0.0          0.0                0.000000
# 4   E09000009       1458.0       1448.0               -0.685871
# 5   E09000016       1051.0       1127.0                7.231208
# 6   E09000017       1147.0       1165.0                1.569311
# 7           0          0.0          0.0                0.000000
# 8           0          0.0          0.0                0.000000
# 9           0          0.0          0.0                0.000000
# 10          0          0.0          0.0                0.000000
# 11          0          0.0          0.0                0.000000
# 12          0          0.0          0.0                0.000000
# 13  E09000011       1343.0       1278.0               -4.839911
# 14          0          0.0          0.0                0.000000
# 15          0          0.0          0.0                0.000000
# 16          0          0.0          0.0                0.000000
# 17  E09000026       1226.0       1231.0                0.407830
# 18          0          0.0          0.0                0.000000
# 19          0          0.0          0.0                0.000000
# 20          0          0.0          0.0                0.000000
# 21          0          0.0          0.0                0.000000
# 22  E09000013       1928.0       2200.0               14.107884
# 23  E09000020       3474.0       2919.0              -15.975820
# 24  E09000033       2998.0       2646.0              -11.741161
# 25  E09000007       1921.0       2217.0               15.408641
# 26  E09000030       1694.0       1723.0                1.711924
# 27  E09000019       2083.0       1800.0              -13.586174
# 28          0          0.0          0.0                0.000000
# 29          0          0.0          0.0                0.000000
# 30  E09000025       1351.0       1407.0                4.145078
# 31  E09000002       1104.0       1150.0                4.166667
# 32  E09000001       1998.0       1851.0               -7.357357

# %% [markdown]
# Global increasing rate of long-term rental price between 2020 and 2022 is 4.1%.
#
# In the plot, the blue colours indicate a higher increasing rate than global and the grey colours indicates a lower increasing rate than global.

# %%
# Long-term increasing rate

fig, ax = plt.subplots(1,1, figsize=(12,9))

# create discrete colormap
cmap = colors.ListedColormap(['grey','grey','silver','silver','gainsboro','thistle','orchid','purple','indigo'])
bounds = [-16.1,-12.1,-8.1,-4.1,0,0.000001,4.1,8.1,12.1,16.1]
norm = colors.BoundaryNorm(bounds, cmap.N)

longterm_merge.plot(ax=ax,figsize=(12,8), marker='*', markersize=0.25,  
         column='increase_rate_longterm',legend=True,cmap=cmap, norm=norm,edgecolor='white',legend_kwds={'shrink': 0.8})
         

track.plot(ax=ax, edgecolor='steelblue', linewidth=2.5)
stations.plot(ax=ax, column='STATION_NA', color='steelblue')

#set a legend
mylabels= ['Elizabeth Line', 'Stations']
ax.legend(track, loc='lower right', frameon=False, labels=mylabels)

# Set the x and y limits
ax.set_xlim(501000,563000)
ax.set_ylim(155000,202000)

plt.savefig("Long-term.png", bbox_inches = 'tight') 
plt.axis('off')
plt.suptitle("Rental price increasing rate along Elizabeth line between 2020 and 2022", y=0.9, size=24, **tfont)
plt.title("Long-term, by borough (%)", loc='left', size=16,**afont)
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# /tmp/ipykernel_2515/3622834842.py:19: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend(track, loc='lower right', frameon=False, labels=mylabels)
# Text(0.0, 1.0, 'Long-term, by borough (%)')

# %% [markdown]
# ## 5. Description analysis

# %% [markdown]
# ### Introduction
#
# This section check whether the Airbnb hosts used 'Elizabeth line' in the description of the listing when advertising each property, in 2020 and 2022.

# %%
# copy the raw data
airbnb_22 = airbnb_22_raw.copy()

# %%
# Check the column data type
airbnb_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69351 entries, 0 to 69350
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            69351 non-null  int64
#  1   listing_url                                   69351 non-null  object
#  2   scrape_id                                     69351 non-null  int64
#  3   last_scraped                                  69351 non-null  object
#  4   source                                        69351 non-null  object
#  5   name                                          69330 non-null  object
#  6   description                                   67832 non-null  object
#  7   neighborhood_overview                         39964 non-null  object
#  8   picture_url                                   69351 non-null  object
#  9   host_id                                       69351 non-null  int64
#  10  host_url                                      69351 non-null  object
#  11  host_name                                     69346 non-null  object
#  12  host_since                                    69346 non-null  object
#  13  host_location                                 56984 non-null  object
#  14  host_about                                    36946 non-null  object
#  15  host_response_time                            42830 non-null  object
#  16  host_response_rate                            42830 non-null  object
#  17  host_acceptance_rate                          45090 non-null  object
#  18  host_is_superhost                             69332 non-null  object
#  19  host_thumbnail_url                            69346 non-null  object
#  20  host_picture_url                              69346 non-null  object
#  21  host_neighbourhood                            43597 non-null  object
#  22  host_listings_count                           69346 non-null  float64
#  23  host_total_listings_count                     69346 non-null  float64
#  24  host_verifications                            69351 non-null  object
#  25  host_has_profile_pic                          69346 non-null  object
#  26  host_identity_verified                        69346 non-null  object
#  27  neighbourhood                                 39965 non-null  object
#  28  neighbourhood_cleansed                        69351 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      69351 non-null  float64
#  31  longitude                                     69351 non-null  float64
#  32  property_type                                 69351 non-null  object
#  33  room_type                                     69351 non-null  object
#  34  accommodates                                  69351 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                69220 non-null  object
#  37  bedrooms                                      65922 non-null  float64
#  38  beds                                          68151 non-null  float64
#  39  amenities                                     69351 non-null  object
#  40  price                                         69351 non-null  object
#  41  minimum_nights                                69351 non-null  int64
#  42  maximum_nights                                69351 non-null  int64
#  43  minimum_minimum_nights                        69348 non-null  float64
#  44  maximum_minimum_nights                        69348 non-null  float64
#  45  minimum_maximum_nights                        69348 non-null  float64
#  46  maximum_maximum_nights                        69348 non-null  float64
#  47  minimum_nights_avg_ntm                        69348 non-null  float64
#  48  maximum_nights_avg_ntm                        69348 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              69351 non-null  object
#  51  availability_30                               69351 non-null  int64
#  52  availability_60                               69351 non-null  int64
#  53  availability_90                               69351 non-null  int64
#  54  availability_365                              69351 non-null  int64
#  55  calendar_last_scraped                         69351 non-null  object
#  56  number_of_reviews                             69351 non-null  int64
#  57  number_of_reviews_ltm                         69351 non-null  int64
#  58  number_of_reviews_l30d                        69351 non-null  int64
#  59  first_review                                  52571 non-null  object
#  60  last_review                                   52571 non-null  object
#  61  review_scores_rating                          52571 non-null  float64
#  62  review_scores_accuracy                        51549 non-null  float64
#  63  review_scores_cleanliness                     51562 non-null  float64
#  64  review_scores_checkin                         51515 non-null  float64
#  65  review_scores_communication                   51548 non-null  float64
#  66  review_scores_location                        51517 non-null  float64
#  67  review_scores_value                           51514 non-null  float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              69351 non-null  object
#  70  calculated_host_listings_count                69351 non-null  int64
#  71  calculated_host_listings_count_entire_homes   69351 non-null  int64
#  72  calculated_host_listings_count_private_rooms  69351 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   69351 non-null  int64
#  74  reviews_per_month                             52571 non-null  float64
# dtypes: float64(24), int64(17), object(34)
# memory usage: 39.7+ MB

# %%
# Drop all rows where the description is NaN:
airbnb_22 = airbnb_22.dropna(subset=['description'])

# Find the columns with 'Elizabeth line' in 2022 and ignore the case
# Create the dataframe with Elizabeth line description
el22 = airbnb_22[
    airbnb_22.description.str.contains(r'Elizabeth line', regex=True, flags=re.IGNORECASE)
].description
el22
# Out:
# 690      The property is a Victorian cottage with 2 bed...
# 1601     Our spacious, light and quiet apartment combin...
# 1638     Our house is 30 minutes away central London gr...
# 1793     BOOK A HOUSE - GET A HOME<br /><br />You will ...
# 3332     Enjoy all the best that East London has to off...
#                                ...
# 68581    This 3 bedrooms flat in the residential area o...
# 68586    Your family will be close to everything when y...
# 69265    With views of the Thames river in every window...
# 69274    Located on the 1st floor of the building, kick...
# 69305    A lovely, cosy double room in a spacious apart...
# Name: description, Length: 270, dtype: object

# %%
print(f'The number of houses with the Elizabeth line description in 2022 is {len(el22)}')
# Out:
# The number of houses with the Elizabeth line description in 2022 is 270

# %%
# Do the same process to load and check the data from 2020
airbnb_20 = airbnb_20_raw.copy()

# Drop all rows where the description is NaN:
airbnb_20 = airbnb_20.dropna(subset=['description'])

# Find the columns with 'Elizabeth line' in 2020 and ignore the case
# Create the dataframe with Elizabeth line description
el20 = airbnb_20[
    airbnb_20.description.str.contains(r'Elizabeth line', regex=True, flags=re.IGNORECASE)
].description
el20
# Out:
# 2398     ASK - Our spacious, light and quiet apartment ...
# 20028    This two bedroom penthouse apartment is locate...
# 20029    This one bedroom apartment is located on the f...
# 20030    This one bedroom apartment is located on the f...
# 35279    This spacious 2 Bedroom apartment is on buzzin...
# 35330    This spacious 2 Bedroom apartment is on buzzin...
# 35399    This spacious 2 Bedroom apartment is on buzzin...
# 37634    I defined my place as the happiness in ones li...
# 41645    Bright and airy, newly refurbished and fully e...
# 49264    My spacious, light and quiet apartment is set ...
# 56050    The unique Manhattan loft style apartment is l...
# 61954    This double room in a semi-detached house arra...
# 61960    This double room in a semi-detached house arra...
# 71014    Modern Mansionnate recently refurbished with q...
# Name: description, dtype: object

# %%
print(f'The number of houses with the Elizabeth line description in 2020 is {len(el20)}')
# Out:
# The number of houses with the Elizabeth line description in 2020 is 14

# %%
# Expand the row width to view the discription
pd.set_option('max_colwidth',1500)

# %%
el20
# Out:
# 2398     ASK - Our spacious, light and quiet apartment combines the best charm of London: the juxtaposition of old and new.  Located in the gated Heritage Quarter which forms the heart of the Royal Arsenal, with a Thames River view, it offers contemporary comfort with period features, WIFI and easy transport to all London destinations by Thames Clipper, Train & DLR/Tube. (High Speed Elizabeth Line Opening 2020 with direct journey to Oxford Street - Heathrow).  Perfect for London City Airport, Excel & O2.<br /><br /><b>The space</b><br />Be a part of history & stay in a home that has consistently been ranked as one of AirBnb's & HomeAway's very best London properties...A welcome respite after a day sight-seeing or working in London, come 'home' to this unique and spacious (over a thousand sq. ft.), window-filled, apartment with many original architectural features set within the exclusive, gated, heritage area of the prestigious, award-winning Royal Arsenal Riverside. This split-level, well-appo
# 20028                                                                   This two bedroom penthouse apartment is located on the fifth floor (with lift to the fourth). It is excellent for friends and families and there is a sofa bed in the reception room to accommodate additional guests. .A reasonable wifi service is included in the rental.<br />It is located in a converted warehouse building with lots of original features and is very close to Farringdon station. Please note that there is some audibility in the trains when the double glazed windows are open. Kitchens are equipped with dishwashers, microwaves and full size fridge freezers have been provided along with little home essentials such as free WiFi and Satellite TV so you can enjoy your time indoors too.<br /><br />The nearest station is Farringdon for direct Thameslink rail services to Luton and Gatwick airports, Elizabeth line services and Northern, Circle and Hammersmith and City lines.<br /><br />Discounts available for longer stays.
# 20029                                                           This one bedroom apartment is located on the fourth floor (with lift). It is excellent for couples, solo adventurers, and business travellers and there is a sofa bed in the reception room to accommodate additional guests. . A reasonable wifi service is included in the rental.<br />It is located in a converted warehouse building with lots of original features and is very close to Farringdon station. Please note that there is some audibility in the trains when the double glazed windows are open. Kitchens are equipped with dishwashers, microwaves and full size fridge freezers have been provided along with little home essentials such as free WiFi and Satellite TV so you can enjoy your time indoors too.<br /><br />The nearest station is Farringdon for direct Thameslink rail services to Luton and Gatwick airports, Elizabeth line services and Northern, Circle and Hammersmith and City lines.<br /><br />Discounts available for longer stays.
# 20030                                                           This one bedroom apartment is located on the fourth floor (with lift). It is excellent for couples, solo adventurers, and business travellers and there is a sofa bed in the reception room to accommodate additional guests. . A reasonable wifi service is included in the rental.<br />It is located in a converted warehouse building with lots of original features and is very close to Farringdon station. Please note that there is some audibility in the trains when the double glazed windows are open. Kitchens are equipped with dishwashers, microwaves and full size fridge freezers have been provided along with little home essentials such as free WiFi and Satellite TV so you can enjoy your time indoors too.<br /><br />The nearest station is Farringdon for direct Thameslink rail services to Luton and Gatwick airports, Elizabeth line services and Northern, Circle and Hammersmith and City lines.<br /><br />Discounts available for longer stays.
# 35279    This spacious 2 Bedroom apartment is on buzzing Queensway, right across from Bayswater station and just a short distance from Hyde Park as well as trendy Notting Hill.  Queensway station for the short ride to Marble Arch and Oxford Street is 2 minutes away.  Paddington station for the Heathrow Express and the Elizabeth Line is 10 minutes’ walk or 1 stop from Bayswater. There is garage car parking (paid) moments from your apartment.  This lively area has a huge range of restaurants, coffee shops.<br /><br /><b>The space</b><br />Your good sized 2 Bedroom apartment has just (April 2018) been refreshed by our interior designer with a number of great homely touches to ensure that your London apartment feels like a home from home.  Located on the 2nd floor (2 flights of stairs) on lively Queensway, Bayswater, just across from Bayswater Station this is an amazing location with so much of central London in easy walking distance.  The Princess Diana Memorial Fountain and the rest of Hyde Park
# 35330    This spacious 2 Bedroom apartment is on buzzing Queensway, right across from Bayswater station and just a short distance from Hyde Park as well as trendy Notting Hill.  Queensway station for the short ride to Marble Arch and Oxford Street is 2 minutes away.  Paddington station for the Heathrow Express and the Elizabeth Line is 10 minutes’ walk or 1 stop from Bayswater. There is garage car parking (paid) moments from your apartment.  This lively area has a huge range of restaurants, coffee shops.<br /><br /><b>The space</b><br />Your good sized 2 Bedroom apartment has just (April 2018) been refreshed by our interior designer with a number of great homely touches to ensure that your London apartment feels like a home from home.  Located on the 1st floor (1 flight of stairs) on lively Queensway, Bayswater, just across from Bayswater Station this is an amazing location with so much of central London in easy walking distance.  The Princess Diana Memorial Fountain and the rest of Hyde Park a
# 35399    This spacious 2 Bedroom apartment is on buzzing Queensway, right across from Bayswater station and just a short distance from Hyde Park as well as trendy Notting Hill.  Queensway station for the short ride to Marble Arch and Oxford Street is 2 minutes away.  Paddington station for the Heathrow Express and the Elizabeth Line is 10 minutes’ walk or 1 stop from Bayswater. There is garage car parking (paid) moments from your apartment.  This lively area has a huge range of restaurants, coffee shops.<br /><br /><b>The space</b><br />Your good sized 2 Bedroom apartment has just (April 2018) been refreshed by our interior designer with a number of great homely touches to ensure that your London apartment feels like a home from home.  Located on the 3rd floor (3 flights of stairs) on lively Queensway, Bayswater, just across from Bayswater Station this is an amazing location with so much of central London in easy walking distance.  The Princess Diana Memorial Fountain and the rest of Hyde Park
# 37634                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                I defined my place as the happiness in ones life. It has all the quality amenities and add-ons that you will not find elsewhere. You'll have your own sanctuary in your room with comfort; while as much as the whole place for sharing with me and my dog.<br /><br />The room has a Futon Company double bed, a 46" flat screen Full HD TV, comes with cabinets, side lamp and blinds.  40 mins into Liverpool Street London by Cross Rail (Elizabeth Line). <br /><br />New Lidl supermarket 2 mins walk.
# 41645                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Bright and airy, newly refurbished and fully equipped 1 bedroom apartment. 12 minute walk or short bus-ride to Manor Park station (soon to be the new Elizabeth line) or Leytonstone or Wanstead on the Central Line. The Aldersbrook Conservation Area is a beautiful Edwardian estate, surrounded by greenspace and yet still well connected to Westfield in Stratford, Canary Wharf, the Financial City, the Westend and Stanstead Airport.
# 49264    My spacious, light and quiet apartment is set within the historic Royal Arsenal. It is a modern apartment with lift access, it offers WIFI and easy transport to all London destinations by Thames Clipper, Train & DLR/Tube. (High Speed Elizabeth Line Opening 2020 with direct journey to Oxford Street - Heathrow). Perfect for London City Airport, Excel & O2. You will have private access to a large balcony with amazing views of the Thames, City Airport, heritage buildings and Wellington Park.<br /><br /><b>The space</b><br />The Royal Arsenal Riverside comprises listed Georgian & Victorian buildings. Wellington Park, Greenwich Heritage Centre, Dial Arch Gastro Pub (where Arsenal Football Club was founded), Boulangerie Jade, The Taproom-Hop Stuff Brewery, The Guard House, Con Gusto, Tesco's Express, Mark's & Spencer Food Hall, Sainsbury's Local and 7R Performance Gym. The Thames Clipper River Boat direct to London attractions is at the Pier a few minutes away, the new Elizabeth Line High Spe
# 56050                                                                                                                                                                                                                                                                                                                                        The unique Manhattan loft style apartment is located  in the historic market town of Romford. On your doorstep you will also find an array of shopping options including the Liberty Centre, the Brewery Leisure Scheme and the historic Romford market. In addition to this Lofthaus is conveniently positioned within a seven minute walk to Romford  station part of the new Elizabeth line on the eastern section of the Crossrail development.<br /><br /><b>The space</b><br />The Manhattan loft style apartment boats 2000 sq feet of space with Arch angled windows to let light in all day. The double height ceiling with luxury bathroom and kitchen makes it the perfect place to stay.
# 61954                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         This double room in a semi-detached house arranged over two floors has a contemporary composition throughout. The house has three bedrooms, a bathroom and a toilet. It is ideal for a single occupant. <br /><br />Half a mile from Acton Main Line (forthcoming Elizabeth line) and North Acton tube stations (Central line). North Acton Playing Fields are circa 100 yards away. You can also pick up Overground trains from Acton Central that take you to Highbury & Islington in 30 minutes.
# 61960                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          This double room in a semi-detached house arranged over two floors has a contemporary composition throughout. The house has three bedrooms, a bathroom and a toilet. It is ideal for a single occupant.<br /><br />Half a mile from Acton Main Line (forthcoming Elizabeth line) and North Acton tube stations (Central line). North Acton Playing Fields are circa 100 yards away. You can also pick up Overground trains from Acton Central that take you to Highbury & Islington in 30 minutes.
# 71014                                                                                                                                                                                                                                                                           Modern Mansionnate recently refurbished with quiet neighbourhood, easy access to London Heathrow and Central London via Elizabeth Line is now available to book. We are professional working hosts ready to welcome you in quiet distant and easy access to city center and major attractions. Railway station is just 7 min walk from the property with local amenities shops like Asda, Tesco at walking distance. Restaurants, takeaways, off license stores, major buses to Heathrow 140, x140, 195, 90, H98, E6<br /><br /><b>The space</b><br />The neighbourhood is quiet, friendly and welcoming.  One of its peace of mind whilst your stay at our property. Easy access to local shops, railways, buses and friendly stay with young professional pair.
# Name: description, dtype: object

# %% [markdown]
# ## 6. Radius analysis for airbnb listing prices

# %% [markdown]
# ### Introduction
#
# In this section, the listings of Airbnb will be examined based a radial distance from the stations sub setting process. After performing the sub setting, the median prices and number of listings will be analyzed from an overall and station by station criteria.

# %% [markdown]
# ### Reading the Airbnb data

# %%
air_2020 = airbnb_2020.copy()
print(f"Data frame is {air_2020.shape[0]:,} x {air_2020.shape[1]}")
# Out:
# Data frame is 74,184 x 74

# %%
air_2022 = airbnb_2022.copy()
print(f"Data frame is {air_2020.shape[0]:,} x {air_2020.shape[1]}")
# Out:
# Data frame is 74,184 x 74

# %% [markdown]
# ### Subsetting the listings data

# %% [markdown]
# #### Distance to station

# %%
# Creating a distance to station column in each dataset
# Read the geodataframes
geo_air_2020 = gpd.GeoDataFrame(air_2020, geometry=gpd.points_from_xy(air_2020.longitude, air_2020.latitude), crs="EPSG:4326")
geo_air_2022 = gpd.GeoDataFrame(air_2022, geometry=gpd.points_from_xy(air_2022.longitude, air_2022.latitude), crs="EPSG:4326")

# Changing CRS
geo_air_2020.to_crs(crs="EPSG:27700",inplace=True)
geo_air_2022.to_crs(crs="EPSG:27700",inplace=True)

geo_air_2020['dist_to_s'] = geo_air_2020.geometry.apply(lambda x: stations.distance(x).min())
geo_air_2022['dist_to_s'] = geo_air_2022.geometry.apply(lambda x: stations.distance(x).min())

# %%
# 2020 
# Inspecting
geo_air_2020['dist_to_s'].head()
# Out:
# 0    6001.639654
# 1    5387.019564
# 2    3198.559619
# 3     927.498223
# 4    4319.582856
# Name: dist_to_s, dtype: float64

# %%
# Descriptive statistics
geo_air_2020['dist_to_s'].describe()
# Out:
# count    74184.000000
# mean      3839.780589
# std       3257.197047
# min          5.757387
# 25%       1467.727222
# 50%       2899.150563
# 75%       5078.073807
# max      24049.824765
# Name: dist_to_s, dtype: float64

# %%
# Number of listing in the radius
geo_air_2020[geo_air_2020.dist_to_s<1000].shape
# Out:
# (11784, 76)

# %%
# Median price
geo_air_2020[geo_air_2020.dist_to_s<1000].price.median()
# Out:
# 99.0

# %%
# Ploting geometry
fig, ax = plt.subplots(1,1, figsize=(12,9))
geo_air_2020[geo_air_2020.dist_to_s<1000].plot(ax=ax,marker='*',markersize=0.1)
# Out:
# <AxesSubplot:>

# %%
# Number of listing in the radius
geo_air_2020[geo_air_2020.dist_to_s<2000].shape
# Out:
# (25349, 76)

# %%
# Median price
geo_air_2020[geo_air_2020.dist_to_s<2000].price.describe()
# Out:
# count    25349.000000
# mean       135.749543
# std        339.303009
# min          0.000000
# 25%         50.000000
# 50%         90.000000
# 75%        149.000000
# max      18638.000000
# Name: price, dtype: float64

# %%
# Ploting geometry
fig, ax = plt.subplots(1,1, figsize=(12,9))
geo_air_2020[geo_air_2020.dist_to_s<2000].plot(ax=ax,marker='*',markersize=0.1)
# Out:
# <AxesSubplot:>

# %%
# Number of listings
geo_air_2020[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)].shape
# Out:
# (13565, 76)

# %%
# Descriptive statistics
geo_air_2020[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)].price.describe()
# Out:
# count    13565.000000
# mean       118.675418
# std        243.013436
# min          0.000000
# 25%         46.000000
# 50%         82.000000
# 75%        130.000000
# max      18638.000000
# Name: price, dtype: float64

# %%
# Ploting geometry
fig, ax = plt.subplots(1,1, figsize=(12,9))
geo_air_2020[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)].plot(ax=ax,marker='*',markersize=0.1)
# Out:
# <AxesSubplot:>

# %%
# 2022
geo_air_2022['dist_to_s'].head()
# Out:
# 0    5464.913940
# 1    3227.728687
# 2    1380.203430
# 3    1019.550642
# 4     927.498223
# Name: dist_to_s, dtype: float64

# %%
geo_air_2022['dist_to_s'].describe()
# Out:
# count    69351.000000
# mean      3966.567559
# std       3412.100956
# min          3.190962
# 25%       1501.836171
# 50%       2962.861925
# 75%       5282.176950
# max      26310.008788
# Name: dist_to_s, dtype: float64

# %%
geo_air_2022[geo_air_2022.dist_to_s<1000].shape
# Out:
# (10825, 77)

# %%
geo_air_2022[geo_air_2022.dist_to_s<1000].price.median()
# Out:
# 140.0

# %%
fig, ax = plt.subplots(1,1, figsize=(12,9))
geo_air_2022[geo_air_2022.dist_to_s<1000].plot(ax=ax,marker='*',markersize=0.1)
# Out:
# <AxesSubplot:>

# %%
geo_air_2022[geo_air_2022.dist_to_s<2000].shape
# Out:
# (23222, 77)

# %%
geo_air_2022[geo_air_2022.dist_to_s<2000].price.describe()
# Out:
# count    23222.000000
# mean       203.761132
# std        433.981703
# min          0.000000
# 25%         65.000000
# 50%        120.000000
# 75%        215.000000
# max      25000.000000
# Name: price, dtype: float64

# %%
fig, ax = plt.subplots(1,1, figsize=(12,9))
geo_air_2022[geo_air_2022.dist_to_s<2000].plot(ax=ax,marker='*',markersize=0.1)
# Out:
# <AxesSubplot:>

# %%
geo_air_2022[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)].shape
# Out:
# (12397, 77)

# %%
geo_air_2022[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)].price.describe()
# Out:
# count    12397.000000
# mean       184.169073
# std        342.960227
# min          0.000000
# 25%         60.000000
# 50%        103.000000
# 75%        189.000000
# max       9999.000000
# Name: price, dtype: float64

# %%
fig, ax = plt.subplots(1,1, figsize=(12,9))
geo_air_2022[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)].plot(ax=ax,marker='*',markersize=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Overall results

# %%
print(f"2020 Airbnb listings \n1 km radious\nNumber of listings: {geo_air_2020[geo_air_2020.dist_to_s<1000].shape[0]:,}\nMedian price: {geo_air_2020[geo_air_2020.dist_to_s<1000]['price'].median()}.")
# Out:
# 2020 Airbnb listings
# 1 km radious
# Number of listings: 11,784
# Median price: 99.0.

# %%
print(f"2020 Airbnb listings \n1-2 km radious\nNumber of listings: {geo_air_2020[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)].shape[0]:,}\nMedian price: {geo_air_2020[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)]['price'].median()}.")
# Out:
# 2020 Airbnb listings
# 1-2 km radious
# Number of listings: 13,565
# Median price: 82.0.

# %%
print(f"2020 Airbnb listings \n2 km radious\nNumber of listings: {geo_air_2020[geo_air_2020.dist_to_s<2000].shape[0]:,}\nMedian price: {geo_air_2020[geo_air_2020.dist_to_s<2000]['price'].median()}.")
# Out:
# 2020 Airbnb listings
# 2 km radious
# Number of listings: 25,349
# Median price: 90.0.

# %%
print(f"2022 Airbnb listings \n1 km radious\nNumber of listings: {geo_air_2022[geo_air_2022.dist_to_s<1000].shape[0]:,}\nMedian price: {geo_air_2022[geo_air_2022.dist_to_s<1000]['price'].median()}.\nMedian price variation: {(geo_air_2022[geo_air_2022.dist_to_s<1000]['price'].median()-geo_air_2020[geo_air_2020.dist_to_s<1000]['price'].median())/geo_air_2020[geo_air_2020.dist_to_s<1000]['price'].median():,.2%}.")
# Out:
# 2022 Airbnb listings
# 1 km radious
# Number of listings: 10,825
# Median price: 140.0.
# Median price variation: 41.41%.

# %%
print(f"2022 Airbnb listings \n1-2 km radious\nNumber of listings: {geo_air_2022[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)].shape[0]:,}\nMedian price: {geo_air_2022[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)]['price'].median()}\nMedian price variation: {(geo_air_2022[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)]['price'].median()-geo_air_2020[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)]['price'].median())/geo_air_2020[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)]['price'].median():,.2%}.")
# Out:
# 2022 Airbnb listings
# 1-2 km radious
# Number of listings: 12,397
# Median price: 103.0
# Median price variation: 25.61%.

# %%
print(f"2022 Airbnb listings \n2 km radious\nNumber of listings: {geo_air_2022[geo_air_2022.dist_to_s<2000].shape[0]:,}\nMedian price: {geo_air_2022[geo_air_2022.dist_to_s<2000]['price'].median()}\nMedian price variation: {(geo_air_2022[geo_air_2022.dist_to_s<2000]['price'].median()-geo_air_2020[geo_air_2020.dist_to_s<2000]['price'].median())/geo_air_2020[geo_air_2020.dist_to_s<2000]['price'].median():,.2%} .")
# Out:
# 2022 Airbnb listings
# 2 km radious
# Number of listings: 23,222
# Median price: 120.0
# Median price variation: 33.33% .

# %% [markdown]
# ### Spatial joining (Stations name)

# %%
geo_air_2020_js = geo_air_2020.sjoin_nearest(stations,how='inner',distance_col='dist_join')
geo_air_2022_js = geo_air_2022.sjoin_nearest(stations,how='inner',distance_col='dist_join')

# %%
# 2020
geo_air_2020_js.shape
# Out:
# (74184, 83)

# %%
geo_air_2020_js[geo_air_2020_js.dist_to_s<2000].shape
# Out:
# (25349, 83)

# %%
geo_air_2020_js.head()
# Out:
#          id                         listing_url         scrape_id  \
# 0   11551.0  https://www.airbnb.com/rooms/11551  20200824024753.0
# 3   17402.0  https://www.airbnb.com/rooms/17402  20200824024753.0
# 35  47192.0  https://www.airbnb.com/rooms/47192  20200824024753.0
# 51  65908.0  https://www.airbnb.com/rooms/65908  20200824024753.0
# 58  71875.0  https://www.airbnb.com/rooms/71875  20200824024753.0
#
#    last_scraped                                             name  \
# 0    2020-08-26       Arty and Bright London Apartment in Zone 2
# 3    2020-08-27            Superb 3-Bed/2 Bath & Wifi: Trendy W1
# 35   2020-08-26                            Single Room in zone 1
# 51   2020-08-26                      Lovely room in cool Brixton
# 58   2020-08-26  Bright Very Central 1-Bed in W1. King Bed, Wifi
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  description  \
# 0   Unlike most rental apartments out there my flat gives you straight away home feel mainly due to the oil paintings from my own collection, something you rarely find in 5* hotels, let alone budget accommodation! A very well equipped kitchen and a large bathroom, not to mention very fast 250 Mbps Wi-Fi and a 40 inch smart TV. <br />Very close to shops 24hrs and supermarkets providing easy reach to daily essential...not to mention just a 3-minute walk to the fastest (Victoria Line) underground in London.<br /><br /><b>The space</b><br />Amenities<br />Bedding: 1 Double bed, 1 living room with 1 chair that unfolds into a comfortable bed and 1 sofa bed for two, 1 bathroom, 1 kitchen<br />Utilities: Central heating, Wi-fi, 40inch smart TV, Kettle, Toaster, Iron board, Cooker, Fridge, Freezer, Washing machine, crockery, pots, pans, dishes etc. <br />Bed linen is provided along with fresh towels.<br /><br /><b>Guest access</b><br />Guest will have access to the entire apartment<br /><br /><b>Ot
# 3   You'll have a wonderful stay in this superb modern well-equipped recently refurbished apartment in very central desirable arty and foodie Fitzrovia, W1. Free wifi. Walk to tourist London or use the close by tubes. Head in any direction for a great day out. Amazing choice of restaurants, pubs and supermarkets.<br /><br /><b>The space</b><br />This is a wonderful very popular beautiful, spacious, contemporary 3-bed / 2-bath apartment in Fitzroy Street, Fitzrovia, W1 (with unlimited wifi).<br /><br />This is a superb property, which has been recently and fully furnished in a contemporary style. With a recently fitted kitchen, two recently fitted bathrooms, new flooring, recently purchased furniture, beds and mattresses, and redecorated throughout, it makes a great base. London is literally on your doorstep!<br /><br />The apartment is on an upper level (with elevator) and is set out over one floor. <br /><br />It comprises: <br /><br />* Master bedroom (2.89m x 4.19m) with kingsize bed wi
# 35  Hi everyone, welcome to my little haven. My flat is 5 min walk from beautiful Regents Park.<br />Nearest tube stations are Great Portland street,on the Circle & Hammersmith & City and Metropolitan lines, and  Regent's Park tube station on the Bakerloo line.<br /><br /><b>The space</b><br />HI,Welcome to my flat and the location, I'm Dino your host..<br />I am looking forward hearing from YOU...<br /><br />My flat is in Regents park area!!! <br />********************************************<br />Please read this before you contact me...thank you:)<br /><br />Hi, I have been a host for many years, so believe me if I say that I have seen it all, I have!!!.<br /><br />So just something I like to point out, I do all the cleaning myself in the flat what is to a very high standard,so please have respect for that!!!<br />Also, my flat is designed to high standard, so have respect for my interior too !!!<br />I speak out of experience, so if you are a person that leaves a trail of untidiness an
# 51  <b>The space</b><br />Available for you to rent is a lovely double room in a large house in cool Brixton.   <br /> <br />The accommodation is comfortable and stylish with everything you need - free wifi, TV, Egyptian cotton sheets and stylish interiors. There is a private bathroom with separate bath and shower.  <br /> <br />The area is fantastic, both just to explore for itself, and with great transport links to let you explore the rest of London. <br /> <br />There are a choice of Underground Lines, and the Tube Station is a 5 minute walk from the house. It is just a 12 minute ride to Oxford Circus for shopping or 20 minutes into the City of London for business travellers.  <br /> <br />The immediate area is a lively cosmopolitan neighbourhood with something for everyone including high street shops, Marks & Spencers, H&M, Topshop etc. A great market which is now on London's tourist map containing excellent coffee shops, and Franca Manca Pizza Restaurant - winner of UK's best cheap ea
# 58  Clean modern well-equipped apt in very central desirable arty, foodie Fitzrovia, W1. King bed. Free wifi. Walk to tourist London or use the close by tubes.  Head in any direction for a great day out. Amazing choice of restaurants, pubs & supermarkets<br /><br /><b>The space</b><br />You'll have a lovely stay in this beautiful very Central London contemporary apartment located in wonderful Fitzroy Street in the heart of Fitzrovia (W1T 4BL). Offered in excellent condition, it is fully furnished with everything ready to provide an enjoyable and comfortable trip. <br /><br />** You're welcome to Instant Book this property but please check the calendar to make sure your booking does not leave a 2-night void period as we can't fill the gap. The only way we can proceed with such bookings is to split the cost of the 2-night void period with you: YOU WILL OWE AN EXTRA NIGHT'S RENT. If in doubt, please ask and we'll be happy to help (quickly!). A 1-night void or a 3+ night void is fine. To check
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        neighborhood_overview  \
# 0   Not even 10 minutes by metro from Victoria Station there is a community where colours, sounds, flavours make you catapult into a completely new and exotic world. This is precisely the largest Afro-Caribbean London community. As soon as you immerse yourself in the local markets and in the heart of the community to the rhythm of the reggae music that resounds from the locals, you can only understand the artistic, creative and cultural uniqueness. Not surprisingly, people like Bob Marley, David Bowie, Van Gogh, Charlie Chaplin have lived in this area. But what makes Brixton so unique and unexpected? <br />Surely the first thing you notice is the huge amount of local markets and shops. From super-coloured fabrics, fruit and vegetable stand, to the largest selection of butchers and fishmongers you can find in the area, to numerous wig and hairdresser shops, the Brixton markets offer a wide selection of local and Caribbean products. From Brixton Station Road, to the famous Electric Avenue, t
# 3   Location, location, location! You won't find better than this!<br /><br />Situated in Fitzroy Street, W1, we offer a top location in the heart of the West End in trendy Fitzrovia. Voted the best place to live in London by the Sunday Times (March 2016), Fitzrovia is a super central arty foodie paradise location with a villagey feel and Georgian architecture. The area was once home to such writers as Virginia Woolf, George Bernard Shaw and Arthur Rimbaud. Today it is a popular and lively neighbourhood with a residential and business mix and a bustling art scene. Over 50 art galleries (10% of all those in London) operate here. The numerous media companies based in the area feed into a trendy and vibrant buzz.<br /><br />Fitzrovia has more restaurants than you'll ever get to visit (with new ones popping up all the time). Michelin stars, British pub grub, easy Italians and sandwich shops. fish n chips, Peruvian cuisine, Chinese, Greek, Indian, Mexican, Filipino. We've got them all and every
# 35                                                                                                                                     The nearest tube station to my flat is Great Portland street.  <br />3 lines stop there, the Circle line (yellow), the Hammersmith & city line(pink) and the Metropolitan line(purple).<br />The flat is only 3 min walk from lovely Regents park. That my neighbourhood is a very quiet, clean and leafy green residential area. At the same time, my flat is in zone 1 of the tube network and you actually can walk to the west end, max. 30 min. if you like walking.<br />A 5min walk from my place is a very nice independent small Turkish supermarket that is open 7days a week.Also...<br />There is a traditional English Breakfast Cafe.<br />There is a male and female hairdresser. <br />There is a dry cleaners.<br />There is a news paper agent (shop).<br />There is a off licence shop(alcohol).<br />There is a second supermarket a 5min walk that has it's own Deli and Bakery.
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 58  Location, location, location! You won't find better than this!<br /><br />Situated in Fitzroy Street, W1, we offer a top location in the heart of the West End in trendy Fitzrovia. Voted the best place to live in London by the Sunday Times (March 2016), Fitzrovia is a super central arty foodie paradise location with a villagey feel and Georgian architecture. The area was once home to such writers as Virginia Woolf, George Bernard Shaw and Arthur Rimbaud. Today it is a popular and lively neighbourhood with a residential and business mix and a bustling art scene. Over 50 art galleries (10% of all those in London) operate here. The numerous media companies based in the area feed into a trendy and vibrant buzz.<br /><br />Fitzrovia has more restaurants than you'll ever get to visit (with new ones popping up all the time). Michelin stars, British pub grub, easy Italians and sandwich shops. fish n chips, Peruvian cuisine, Chinese, Greek, Indian, Mexican, Filipino. We've got them all and every
#
#                                                                   picture_url  \
# 0   https://a0.muscache.com/pictures/b7afccf4-18e5-4e75-b9d0-39346d5be06b.jpg
# 3   https://a0.muscache.com/pictures/39d5309d-fba7-4ecb-8cae-383dcb3b757c.jpg
# 35            https://a0.muscache.com/pictures/54290798/f46dc405_original.jpg
# 51             https://a0.muscache.com/pictures/4350503/e02629af_original.jpg
# 58            https://a0.muscache.com/pictures/26416186/d382c2f7_original.jpg
#
#      host_id                                  host_url  ... reviews_per_month  \
# 0    43039.0   https://www.airbnb.com/users/show/43039  ...              1.51
# 3    67564.0   https://www.airbnb.com/users/show/67564  ...              0.37
# 35  212734.0  https://www.airbnb.com/users/show/212734  ...              3.09
# 51  322341.0  https://www.airbnb.com/users/show/322341  ...               NaN
# 58   67564.0   https://www.airbnb.com/users/show/67564  ...              0.70
#
#                          geometry    dist_to_s index_right OBJECTID  \
# 0   POINT (530885.122 175377.940)  6001.639654          17       18
# 3   POINT (529075.790 181974.865)   927.498223          17       18
# 35  POINT (528852.745 182831.588)  1772.264940          17       18
# 51  POINT (530700.653 175090.560)  6249.809664          17       18
# 58  POINT (529238.223 182002.362)   859.072886          17       18
#
#               STATION_NA  SIZE_ SE_ANNO_CA    con    dist_join
# 0   Tottenham Court Road  Large       None  Multi  6001.639654
# 3   Tottenham Court Road  Large       None  Multi   927.498223
# 35  Tottenham Court Road  Large       None  Multi  1772.264940
# 51  Tottenham Court Road  Large       None  Multi  6249.809664
# 58  Tottenham Court Road  Large       None  Multi   859.072886
#
# [5 rows x 83 columns]

# %%
geo_air_2020_js.STATION_NA.unique()
# Out:
# array(['Tottenham Court Road', 'Farringdon', 'Paddington', 'Hanwell',
#        'Ealing Broadway', 'Whitechapel', 'Canary Wharf',
#        'Acton Main Line', 'Liverpool Street', 'Maryland', 'Bond Street',
#        'Ilford', 'Forest Gate', 'Heathrow T4', 'Romford', 'Woolwich',
#        'Stratford', 'Southall', 'Manor Park', 'Custom House',
#        'West Ealing', 'Hayes & Harlington', 'Chadwell Heath',
#        'West Drayton', 'Abbey Wood', 'Seven Kings', 'Harold Wood',
#        'Goodmayes', 'Gidea Park', 'Heathrow Central', 'Heathrow T5'],
#       dtype=object)

# %%
# 2022
geo_air_2022_js.shape
# Out:
# (69351, 84)

# %%
geo_air_2022_js[geo_air_2022_js.dist_to_s<2000].shape
# Out:
# (23222, 84)

# %%
geo_air_2022_js.head()
# Out:
#         id                          listing_url       scrape_id last_scraped  \
# 0    13913   https://www.airbnb.com/rooms/13913  20220910194334   2022-09-11
# 5   107048  https://www.airbnb.com/rooms/107048  20220910194334   2022-09-11
# 10  116268  https://www.airbnb.com/rooms/116268  20220910194334   2022-09-11
# 32   38950   https://www.airbnb.com/rooms/38950  20220910194334   2022-09-11
# 37   40228   https://www.airbnb.com/rooms/40228  20220910194334   2022-09-11
#
#              source                                              name  \
# 0       city scrape               Holiday London DB Room Let-on going
# 5       city scrape              A Luxury Studio Suite in Clerkenwell
# 10      city scrape                   DOUBLE ROOM NEAR CENTRAL LONDON
# 32  previous scrape  Room 1 Large Double Bedroom - front ground floor
# 37  previous scrape         Room 4 Cosy Double Bedroom on First Floor
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  description  \
# 0   My bright double bedroom with a large window has a relaxed feeling! It comfortably fits one or two and is centrally located just two blocks from Finsbury Park. Enjoy great restaurants in the area and easy access to easy transport tubes, trains and buses. Babies and children of all ages are welcome.<br /><br /><b>The space</b><br />Hello Everyone,<br /><br />I'm offering my lovely double bedroom in Finsbury Park area (zone 2) for let in a shared apartment. <br />You will share the apartment with me and it is fully furnished with a self catering kitchen. Two people can easily sleep well as the room has a queen size bed. I also have a travel cot for a baby for guest with small children. <br /><br />I will require a deposit up front as a security gesture on both our parts and will be given back to you when you return the keys. <br /><br />I trust anyone who will be responding to this add would treat my home with care and respect . <br /><br />Best Wishes <br /><br />Alina<br /><br /><b>Gue
# 5   Situated in the heart of vibrant Clerkenwell, what many consider to be the creative and culinary capital of London and within a short walk of a multitude of pubs, bars and restaurants. Self contained accommodation with own door, features all the comfort and convenience of a hotel with easy access via keypads and in suite wifi <br /><br />JUST UPGRADED BRAND NEW RENOVATION 1 BED APARTMENT WITH EN-SUITE BATHROOM AND LOUNGE/KITCHENETTE<br /><br /><b>The space</b><br />Luxurious Self Contained One Bedroom Suite centrally located in fashionable St John Street, Clerkenwell.<br /><br />Ideal as a weekday pied-a-terre, as a short term base for professional contractors, consultants etc or just for a leisure stay.<br /><br />Accomodation features all the comfort and convenience of a boutique hotel but at budget hotel rates:<br /><br />Deluxe ensuite bathroom with separate bathtub and wetroom shower (featuring Oriental Basalt finishes and Hansgrohe taps)<br />40 inch Sony LCD TV/DVD <br />Deluxe
# 10  <b>The space</b><br />One lovely double bedroom for one guest only in a quiet area 25 minutes by tube from central London. Guests have use of the kitchen and bathroom, with constant hot water and separate toilet. The room includes a double bed, towels and linen, free WiFi and TV. The apartment is shared with the owner and other guests. The apartment is very clean and tidy and is situated in Bounds Green, a bus ride away from Muswell Hill with it's many stylish bars, cafes and restaurants and a local park minutes away with a great view over London and with 25 minutes to Leicester Square and all London's tourist attractions this is perfectly situated. It is also  only 30 mins train away from the city, the nearest station is Bounds Green  which is roughly around a 10 minute walk  away. <br /><br /><br />The preferred guest would for this accommodation would be for a single person, unfortunately the rooms cannot accommodate families.<br /><br />I look forward to hearing from you.<br /><br
# 32  Room 1  <br />Bright and Spacious Double Bedroom with fitted wardrobes in 3 Bedroom Victorian Terrace House with Garden on quiet street of North London (N17)<br /><br /><b>The space</b><br />PLEASE CONTACT ME BEFORE BOOKING - No refunds!<br /><br />Victorian Terrace  House with garden close to the Underground & 24/7 bus hub. (within walking distance of Piccadilly Line underground stations and Victoria Line, bus interchange and a High Road. Only 20 minutes from the centre & 10 minutes from King's Cross and St Pancras Stations - one of the most connected transport hub in London and Europe.<br /><br />The space: Room 1 <br />This is a large, bright, comfortable double bedroom in a homely, clean, much-loved 4bed house North London  (N17). Very convenient and easy access to public transport. To share with one, easy going guy (me). <br /><br />The place is modest on the outside and lovely on the inside (the room would probably suit someone with similar qualities!).<br /><br />I love travelli
# 37  Double Bedroom  First Floor with double bed<br /><br /><b>The space</b><br />PLEASE CONTACT ME BEFORE BOOKING <br />Victorian tartare house close to the Underground & 24/7 bus hub. (within walking distance of Piccadilly Line underground stations and Victoria Line, bus interchange and a High Road. Only 20 minutes from the centre & 10 minutes from King's Cross and St Pancras Stations - one of the most connected transport hub in London and Europe.<br /><br />The space<br />This is a bright, comfortable room in a homely, clean, much-loved 4bed house North London  (N17). Very convenient and easy access to public transport. To share with one, easy going guy (me). <br /><br />The place is modest on the outside and lovely on the inside (the room would probably suit someone with similar qualities!).<br /><br />I love travelling and meeting interesting people from all over the world, which is why I let this room inexpensively, and only for short periods..<br /><br />Excellent transport links to
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        neighborhood_overview  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Finsbury Park is a friendly melting pot community composed of Turkish, French, Spanish, Middle Eastern, Irish and English families. <br />We have a wonderful variety of international restaurants directly under us on Stroud Green Road. And there are many shops and large Tescos supermarket right next door. <br /><br />But you can also venture up to Crouch End and along Greens Lanes where there will endless choice of Turkish and Middle Eastern cuisines.s
# 5   Clerkenwell & Vicinity Recommendations<br /><br />Breakfast Bars<br />Coffee Workshop - Clerkenwell Rd<br />J&A - off Great Sutton St<br />The Granger - Clerkenwell Green<br />Benugo - Clerkenwell Rd/St John Street junction<br />Goswell Rd Street Coffee - Goswell Rd<br />Sweet Boulangerie - Exmouth Market<br />Ground Floor at Smiths - Charterhouse St<br />Gails - Exmouth Market<br />Modern Pantry - St Johns <br />Cafe Par - St john St<br />Curved Angel (sunny terrace) - Clerkenwell Close<br />The Hope - St John St<br />Fox & Anchor - Charterhouse St<br />Look Mum No Hands - Old St<br />Breakfast Club - Camden Passage, Islington<br /><br />Bars<br />Cocktail Bar at Zetter Townhouse - St Johns Sq<br />Coffee Workshop - Clerkenwell Rd<br />19:20 Pool Bar - Great Sutton St<br />Giant Robot Bar - Clerkenwell Rd<br />The Green - Clerkenwell Green<br />Smiths Bar - Charterhouse St<br />Granger - Clerkenwell Green<br />Cellar Gascon Wine Bar - West Smithfield<br />Tart - Charterhouse St<br />C
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       North London, West Green, Tottenham
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         West Green is an area of North London, England in the United Kingdom and part of the London Borough of Haringey. It is an inner-suburban area located 5.7 miles (9.22 km) north of Charing Cross.<br /><br />The area is mainly residential and includes both Chestnuts and Downhills parks. Its area is roughly defined by Downhills Park in the North and Northeast, by Cornwall Road to the East, a line running between Cranleigh and Stanley Roads to the South, Harringay Road and Stanmore Road to the West and Northwest.
#
#                                                                                                picture_url  \
# 0   https://a0.muscache.com/pictures/miso/Hosting-13913/original/d755aa6d-cebb-4464-80be-2722c921e8d5.jpeg
# 5                                https://a0.muscache.com/pictures/ff065257-7660-4b3d-80b6-34908b228892.jpg
# 10                                           https://a0.muscache.com/pictures/855414/0f978d74_original.jpg
# 32                               https://a0.muscache.com/pictures/ab0c51a0-adc9-40cd-8042-de9d202b1703.jpg
# 37                               https://a0.muscache.com/pictures/82ed75e5-cfb1-480a-b9ac-daa0ddeffd21.jpg
#
#     host_id  ... reviews_per_month                       geometry  \
# 0     54730  ...              0.20  POINT (530901.013 187213.787)
# 5    259088  ...              3.59  POINT (531572.006 182353.814)
# 10   586671  ...              0.29  POINT (530350.368 191957.865)
# 32   167107  ...              0.11  POINT (532676.137 189288.550)
# 37   167107  ...               NaN  POINT (532563.728 189345.700)
#
#        dist_to_s index_right OBJECTID  STATION_NA  SIZE_ SE_ANNO_CA    con  \
# 0    5464.913940          19       20  Farringdon  Large       None  Multi
# 5     569.496622          19       20  Farringdon  Large       None  Multi
# 10  10238.504293          19       20  Farringdon  Large       None  Multi
# 32   7526.886587          19       20  Farringdon  Large       None  Multi
# 37   7570.903745          19       20  Farringdon  Large       None  Multi
#
#        dist_join
# 0    5464.913940
# 5     569.496622
# 10  10238.504293
# 32   7526.886587
# 37   7570.903745
#
# [5 rows x 84 columns]

# %%
geo_air_2022_js.STATION_NA.unique()
# Out:
# array(['Farringdon', 'Paddington', 'Whitechapel', 'Tottenham Court Road',
#        'Bond Street', 'Hanwell', 'Acton Main Line', 'Southall',
#        'Custom House', 'Forest Gate', 'Stratford', 'Ealing Broadway',
#        'Liverpool Street', 'Canary Wharf', 'Maryland', 'Chadwell Heath',
#        'West Drayton', 'Abbey Wood', 'Ilford', 'Heathrow T4', 'Romford',
#        'Woolwich', 'Manor Park', 'West Ealing', 'Seven Kings',
#        'Hayes & Harlington', 'Harold Wood', 'Goodmayes', 'Gidea Park',
#        'Heathrow Central', 'Heathrow T5', 'Brentwood', 'Iver'],
#       dtype=object)

# %%
# 6.

# %% [markdown]
# ### Median price results by stations

# %% [markdown]
# Add the point of the station

# %%
# 2020
# Median price grouping by stations in 1 km radius
result_2020_r_1k = geo_air_2020_js[geo_air_2020_js.dist_to_s<1000].groupby('STATION_NA')['price'].agg('median').sort_values(ascending = False)
result_2020_r_1k.head()
# Out:
# STATION_NA
# Bond Street             206.0
# Tottenham Court Road    146.0
# Harold Wood             117.0
# Farringdon              115.0
# Paddington              114.0
# Name: price, dtype: float64

# %%
# Median price grouping by stations in 2 km radius
result_2020_r_2k = geo_air_2020_js[geo_air_2020_js.dist_to_s<2000].groupby('STATION_NA')['price'].agg('median').sort_values(ascending = False)
result_2020_r_2k.head()
# Out:
# STATION_NA
# Bond Street             186.0
# Tottenham Court Road    125.0
# Paddington              110.0
# Farringdon              100.0
# Liverpool Street        100.0
# Name: price, dtype: float64

# %%
# Median price grouping by stations in 1-2 km radius
result_2020_r_1k_2k = geo_air_2020_js[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)].groupby('STATION_NA')['price'].agg('median').sort_values(ascending = False)
result_2020_r_1k_2k.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:1428: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# STATION_NA
# Bond Street             145.0
# Paddington              109.0
# Liverpool Street         98.0
# Farringdon               92.0
# Tottenham Court Road     90.0
# Name: price, dtype: float64

# %%
# 2022
# Median price grouping by stations in 1 km radius
result_2022_r_1k = geo_air_2022_js[geo_air_2022_js.dist_to_s<1000].groupby('STATION_NA')['price'].agg('median').sort_values(ascending = False)
result_2022_r_1k.head()
# Out:
# STATION_NA
# Bond Street             320.0
# Tottenham Court Road    240.0
# Harold Wood             172.5
# Iver                    171.0
# Liverpool Street        163.0
# Name: price, dtype: float64

# %%
# Median price grouping by stations in 2 km radius
result_2022_r_2k = geo_air_2022_js[geo_air_2022_js.dist_to_s<2000].groupby('STATION_NA')['price'].agg('median').sort_values(ascending = False)
result_2022_r_2k.head()
# Out:
# STATION_NA
# Bond Street             288.0
# Tottenham Court Road    192.0
# Iver                    154.5
# Paddington              150.0
# Harold Wood             145.0
# Name: price, dtype: float64

# %%
# Median price grouping by stations in 1-2 km radius
result_2022_r_1k_2k = geo_air_2022_js[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)].groupby('STATION_NA')['price'].agg('median').sort_values(ascending = False)
result_2022_r_1k_2k.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:1428: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# STATION_NA
# Bond Street         242.0
# Paddington          150.0
# Liverpool Street    134.0
# Heathrow T4         125.0
# Farringdon          125.0
# Name: price, dtype: float64

# %% [markdown]
# #### Merging 2020 results

# %%
# Mergins 1km with 1-2km radius by station
results_2020 = pd.merge(result_2020_r_1k, result_2020_r_1k_2k, right_index = True, left_index = True)
results_2020
# Out:
#                       price_x  price_y
# STATION_NA
# Bond Street             206.0    145.0
# Tottenham Court Road    146.0     90.0
# Harold Wood             117.0     40.0
# Farringdon              115.0     92.0
# Paddington              114.0    109.0
# Liverpool Street        104.5     98.0
# Canary Wharf             80.0     60.0
# Custom House             80.0     75.0
# Stratford                75.0     55.0
# Romford                  73.0     55.0
# Ilford                   61.0     35.0
# Woolwich                 60.0     50.0
# West Ealing              60.0     50.0
# Whitechapel              60.0     70.0
# Ealing Broadway          57.0     46.0
# Acton Main Line          55.5     60.0
# Seven Kings              55.0     40.0
# Heathrow Central         52.0     60.0
# Maryland                 50.0     45.0
# West Drayton             49.0     42.5
# Hayes & Harlington       45.0     40.0
# Manor Park               43.0     41.5
# Hanwell                  42.0     45.0
# Southall                 42.0     33.0
# Abbey Wood               40.0     40.0
# Forest Gate              39.0     37.0
# Chadwell Heath           38.5     46.0
# Heathrow T4              36.0     43.0
# Goodmayes                35.0     50.0
# Gidea Park               35.0     54.5

# %%
# Renaming merged columns
results_2020.rename(columns={'price_x': 'R_1K_2020', 'price_y': 'R_1K_2K_2020'}, inplace=True)
results_2020
# Out:
#                       R_1K_2020  R_1K_2K_2020
# STATION_NA
# Bond Street               206.0         145.0
# Tottenham Court Road      146.0          90.0
# Harold Wood               117.0          40.0
# Farringdon                115.0          92.0
# Paddington                114.0         109.0
# Liverpool Street          104.5          98.0
# Canary Wharf               80.0          60.0
# Custom House               80.0          75.0
# Stratford                  75.0          55.0
# Romford                    73.0          55.0
# Ilford                     61.0          35.0
# Woolwich                   60.0          50.0
# West Ealing                60.0          50.0
# Whitechapel                60.0          70.0
# Ealing Broadway            57.0          46.0
# Acton Main Line            55.5          60.0
# Seven Kings                55.0          40.0
# Heathrow Central           52.0          60.0
# Maryland                   50.0          45.0
# West Drayton               49.0          42.5
# Hayes & Harlington         45.0          40.0
# Manor Park                 43.0          41.5
# Hanwell                    42.0          45.0
# Southall                   42.0          33.0
# Abbey Wood                 40.0          40.0
# Forest Gate                39.0          37.0
# Chadwell Heath             38.5          46.0
# Heathrow T4                36.0          43.0
# Goodmayes                  35.0          50.0
# Gidea Park                 35.0          54.5

# %%
# Mergins previous results with 2 km radius by station
results_2020_total = pd.merge(results_2020, result_2020_r_2k, right_index = True, left_index = True)
results_2020_total
# Out:
#                       R_1K_2020  R_1K_2K_2020  price
# STATION_NA
# Bond Street               206.0         145.0  186.0
# Tottenham Court Road      146.0          90.0  125.0
# Harold Wood               117.0          40.0   49.5
# Farringdon                115.0          92.0  100.0
# Paddington                114.0         109.0  110.0
# Liverpool Street          104.5          98.0  100.0
# Canary Wharf               80.0          60.0   68.0
# Custom House               80.0          75.0   75.0
# Stratford                  75.0          55.0   60.0
# Romford                    73.0          55.0   60.0
# Ilford                     61.0          35.0   50.0
# Woolwich                   60.0          50.0   50.0
# West Ealing                60.0          50.0   50.0
# Whitechapel                60.0          70.0   65.0
# Ealing Broadway            57.0          46.0   50.0
# Acton Main Line            55.5          60.0   59.0
# Seven Kings                55.0          40.0   49.0
# Heathrow Central           52.0          60.0   59.5
# Maryland                   50.0          45.0   48.0
# West Drayton               49.0          42.5   47.5
# Hayes & Harlington         45.0          40.0   40.0
# Manor Park                 43.0          41.5   43.0
# Hanwell                    42.0          45.0   45.0
# Southall                   42.0          33.0   35.0
# Abbey Wood                 40.0          40.0   40.0
# Forest Gate                39.0          37.0   37.0
# Chadwell Heath             38.5          46.0   40.0
# Heathrow T4                36.0          43.0   40.0
# Goodmayes                  35.0          50.0   45.5
# Gidea Park                 35.0          54.5   40.0

# %%
# Renaming 2km radius column
results_2020_total.rename(columns={'price': 'R_2K_2020'}, inplace=True)
results_2020_total
# Out:
#                       R_1K_2020  R_1K_2K_2020  R_2K_2020
# STATION_NA
# Bond Street               206.0         145.0      186.0
# Tottenham Court Road      146.0          90.0      125.0
# Harold Wood               117.0          40.0       49.5
# Farringdon                115.0          92.0      100.0
# Paddington                114.0         109.0      110.0
# Liverpool Street          104.5          98.0      100.0
# Canary Wharf               80.0          60.0       68.0
# Custom House               80.0          75.0       75.0
# Stratford                  75.0          55.0       60.0
# Romford                    73.0          55.0       60.0
# Ilford                     61.0          35.0       50.0
# Woolwich                   60.0          50.0       50.0
# West Ealing                60.0          50.0       50.0
# Whitechapel                60.0          70.0       65.0
# Ealing Broadway            57.0          46.0       50.0
# Acton Main Line            55.5          60.0       59.0
# Seven Kings                55.0          40.0       49.0
# Heathrow Central           52.0          60.0       59.5
# Maryland                   50.0          45.0       48.0
# West Drayton               49.0          42.5       47.5
# Hayes & Harlington         45.0          40.0       40.0
# Manor Park                 43.0          41.5       43.0
# Hanwell                    42.0          45.0       45.0
# Southall                   42.0          33.0       35.0
# Abbey Wood                 40.0          40.0       40.0
# Forest Gate                39.0          37.0       37.0
# Chadwell Heath             38.5          46.0       40.0
# Heathrow T4                36.0          43.0       40.0
# Goodmayes                  35.0          50.0       45.5
# Gidea Park                 35.0          54.5       40.0

# %% [markdown]
# #### Merging 2022 results

# %%
# Mergins 1km with 1-2km radius by station
results_2022 = pd.merge(result_2022_r_1k, result_2022_r_1k_2k, right_index = True, left_index = True)
results_2022
# Out:
#                       price_x  price_y
# STATION_NA
# Bond Street             320.0    242.0
# Tottenham Court Road    240.0    125.0
# Harold Wood             172.5     80.0
# Iver                    171.0     46.0
# Liverpool Street        163.0    134.0
# Paddington              154.0    150.0
# Farringdon              147.0    125.0
# Canary Wharf            120.0     75.0
# Custom House            120.0     99.5
# Stratford                97.0     80.0
# Ealing Broadway          90.0     78.0
# Heathrow Central         89.0    111.0
# West Ealing              86.5     55.0
# Hanwell                  85.0     72.5
# Ilford                   85.0     55.0
# Romford                  81.5     65.0
# Southall                 80.0     65.0
# Hayes & Harlington       78.0     57.0
# Whitechapel              78.0     85.0
# Woolwich                 78.0     74.0
# West Drayton             70.0     77.0
# Goodmayes                67.0     48.0
# Acton Main Line          66.0     75.5
# Maryland                 66.0     60.0
# Abbey Wood               60.0     59.0
# Forest Gate              60.0     58.0
# Seven Kings              59.0     59.0
# Chadwell Heath           55.0     57.0
# Manor Park               47.5     50.0
# Heathrow T4              39.0    125.0
# Gidea Park               36.0     73.0

# %%
# Renaming merged columns
results_2022.rename(columns={'price_x': 'R_1K_2022', 'price_y': 'R_1K_2K_2022'}, inplace=True)
results_2022
# Out:
#                       R_1K_2022  R_1K_2K_2022
# STATION_NA
# Bond Street               320.0         242.0
# Tottenham Court Road      240.0         125.0
# Harold Wood               172.5          80.0
# Iver                      171.0          46.0
# Liverpool Street          163.0         134.0
# Paddington                154.0         150.0
# Farringdon                147.0         125.0
# Canary Wharf              120.0          75.0
# Custom House              120.0          99.5
# Stratford                  97.0          80.0
# Ealing Broadway            90.0          78.0
# Heathrow Central           89.0         111.0
# West Ealing                86.5          55.0
# Hanwell                    85.0          72.5
# Ilford                     85.0          55.0
# Romford                    81.5          65.0
# Southall                   80.0          65.0
# Hayes & Harlington         78.0          57.0
# Whitechapel                78.0          85.0
# Woolwich                   78.0          74.0
# West Drayton               70.0          77.0
# Goodmayes                  67.0          48.0
# Acton Main Line            66.0          75.5
# Maryland                   66.0          60.0
# Abbey Wood                 60.0          59.0
# Forest Gate                60.0          58.0
# Seven Kings                59.0          59.0
# Chadwell Heath             55.0          57.0
# Manor Park                 47.5          50.0
# Heathrow T4                39.0         125.0
# Gidea Park                 36.0          73.0

# %%
# Mergins previous results with 2 km radius by station
results_2022_total = pd.merge(results_2022, result_2022_r_2k, right_index = True, left_index = True)
results_2022_total
# Out:
#                       R_1K_2022  R_1K_2K_2022  price
# STATION_NA
# Bond Street               320.0         242.0  288.0
# Tottenham Court Road      240.0         125.0  192.0
# Harold Wood               172.5          80.0  145.0
# Iver                      171.0          46.0  154.5
# Liverpool Street          163.0         134.0  140.0
# Paddington                154.0         150.0  150.0
# Farringdon                147.0         125.0  134.0
# Canary Wharf              120.0          75.0   85.0
# Custom House              120.0          99.5  105.0
# Stratford                  97.0          80.0   85.0
# Ealing Broadway            90.0          78.0   86.0
# Heathrow Central           89.0         111.0  105.5
# West Ealing                86.5          55.0   65.0
# Hanwell                    85.0          72.5   80.0
# Ilford                     85.0          55.0   65.0
# Romford                    81.5          65.0   65.0
# Southall                   80.0          65.0   72.0
# Hayes & Harlington         78.0          57.0   70.0
# Whitechapel                78.0          85.0   80.0
# Woolwich                   78.0          74.0   75.0
# West Drayton               70.0          77.0   70.0
# Goodmayes                  67.0          48.0   60.0
# Acton Main Line            66.0          75.5   73.0
# Maryland                   66.0          60.0   64.0
# Abbey Wood                 60.0          59.0   60.0
# Forest Gate                60.0          58.0   59.0
# Seven Kings                59.0          59.0   59.0
# Chadwell Heath             55.0          57.0   57.0
# Manor Park                 47.5          50.0   49.0
# Heathrow T4                39.0         125.0   75.0
# Gidea Park                 36.0          73.0   50.0

# %%
# Renaming 2km column
results_2022_total.rename(columns={'price': 'R_2K_2022'}, inplace=True)
results_2022_total
# Out:
#                       R_1K_2022  R_1K_2K_2022  R_2K_2022
# STATION_NA
# Bond Street               320.0         242.0      288.0
# Tottenham Court Road      240.0         125.0      192.0
# Harold Wood               172.5          80.0      145.0
# Iver                      171.0          46.0      154.5
# Liverpool Street          163.0         134.0      140.0
# Paddington                154.0         150.0      150.0
# Farringdon                147.0         125.0      134.0
# Canary Wharf              120.0          75.0       85.0
# Custom House              120.0          99.5      105.0
# Stratford                  97.0          80.0       85.0
# Ealing Broadway            90.0          78.0       86.0
# Heathrow Central           89.0         111.0      105.5
# West Ealing                86.5          55.0       65.0
# Hanwell                    85.0          72.5       80.0
# Ilford                     85.0          55.0       65.0
# Romford                    81.5          65.0       65.0
# Southall                   80.0          65.0       72.0
# Hayes & Harlington         78.0          57.0       70.0
# Whitechapel                78.0          85.0       80.0
# Woolwich                   78.0          74.0       75.0
# West Drayton               70.0          77.0       70.0
# Goodmayes                  67.0          48.0       60.0
# Acton Main Line            66.0          75.5       73.0
# Maryland                   66.0          60.0       64.0
# Abbey Wood                 60.0          59.0       60.0
# Forest Gate                60.0          58.0       59.0
# Seven Kings                59.0          59.0       59.0
# Chadwell Heath             55.0          57.0       57.0
# Manor Park                 47.5          50.0       49.0
# Heathrow T4                39.0         125.0       75.0
# Gidea Park                 36.0          73.0       50.0

# %% [markdown]
# #### Merging 2020 and 2022 results

# %%
# Merging the 2020 and 2022 results by station
results_2020_2022_total = pd.merge(results_2020_total, results_2022_total, right_index = True, left_index = True)
results_2020_2022_total
# Out:
#                       R_1K_2020  R_1K_2K_2020  R_2K_2020  R_1K_2022  \
# STATION_NA
# Bond Street               206.0         145.0      186.0      320.0
# Tottenham Court Road      146.0          90.0      125.0      240.0
# Harold Wood               117.0          40.0       49.5      172.5
# Farringdon                115.0          92.0      100.0      147.0
# Paddington                114.0         109.0      110.0      154.0
# Liverpool Street          104.5          98.0      100.0      163.0
# Canary Wharf               80.0          60.0       68.0      120.0
# Custom House               80.0          75.0       75.0      120.0
# Stratford                  75.0          55.0       60.0       97.0
# Romford                    73.0          55.0       60.0       81.5
# Ilford                     61.0          35.0       50.0       85.0
# Woolwich                   60.0          50.0       50.0       78.0
# West Ealing                60.0          50.0       50.0       86.5
# Whitechapel                60.0          70.0       65.0       78.0
# Ealing Broadway            57.0          46.0       50.0       90.0
# Acton Main Line            55.5          60.0       59.0       66.0
# Seven Kings                55.0          40.0       49.0       59.0
# Heathrow Central           52.0          60.0       59.5       89.0
# Maryland                   50.0          45.0       48.0       66.0
# West Drayton               49.0          42.5       47.5       70.0
# Hayes & Harlington         45.0          40.0       40.0       78.0
# Manor Park                 43.0          41.5       43.0       47.5
# Hanwell                    42.0          45.0       45.0       85.0
# Southall                   42.0          33.0       35.0       80.0
# Abbey Wood                 40.0          40.0       40.0       60.0
# Forest Gate                39.0          37.0       37.0       60.0
# Chadwell Heath             38.5          46.0       40.0       55.0
# Heathrow T4                36.0          43.0       40.0       39.0
# Goodmayes                  35.0          50.0       45.5       67.0
# Gidea Park                 35.0          54.5       40.0       36.0
#
#                       R_1K_2K_2022  R_2K_2022
# STATION_NA
# Bond Street                  242.0      288.0
# Tottenham Court Road         125.0      192.0
# Harold Wood                   80.0      145.0
# Farringdon                   125.0      134.0
# Paddington                   150.0      150.0
# Liverpool Street             134.0      140.0
# Canary Wharf                  75.0       85.0
# Custom House                  99.5      105.0
# Stratford                     80.0       85.0
# Romford                       65.0       65.0
# Ilford                        55.0       65.0
# Woolwich                      74.0       75.0
# West Ealing                   55.0       65.0
# Whitechapel                   85.0       80.0
# Ealing Broadway               78.0       86.0
# Acton Main Line               75.5       73.0
# Seven Kings                   59.0       59.0
# Heathrow Central             111.0      105.5
# Maryland                      60.0       64.0
# West Drayton                  77.0       70.0
# Hayes & Harlington            57.0       70.0
# Manor Park                    50.0       49.0
# Hanwell                       72.5       80.0
# Southall                      65.0       72.0
# Abbey Wood                    59.0       60.0
# Forest Gate                   58.0       59.0
# Chadwell Heath                57.0       57.0
# Heathrow T4                  125.0       75.0
# Goodmayes                     48.0       60.0
# Gidea Park                    73.0       50.0

# %%
# Calculating the percentage variations at each radius between 2020 and 2022
results_2020_2022_total['diff_1K'] = round((results_2020_2022_total['R_1K_2022']-results_2020_2022_total['R_1K_2020'])/results_2020_2022_total['R_1K_2020'],3)
results_2020_2022_total['diff_1K_2K'] = round((results_2020_2022_total['R_1K_2K_2022']-results_2020_2022_total['R_1K_2K_2020'])/results_2020_2022_total['R_1K_2K_2020'],3)
results_2020_2022_total['diff_2K'] = round((results_2020_2022_total['R_2K_2022']-results_2020_2022_total['R_2K_2020'])/results_2020_2022_total['R_2K_2020'],3)

# Assigning percentage format
results_2020_2022_total.style.format({
    'diff_1K': '{:,.2%}'.format,
    'diff_1K_2K': '{:,.2%}'.format,
    'diff_2K': '{:,.2%}'.format,
})

# Sorting by 1k radius difference
results_2020_2022_total.sort_values('diff_1K',ascending=False)
# Out:
#                       R_1K_2020  R_1K_2K_2020  R_2K_2020  R_1K_2022  \
# STATION_NA
# Hanwell                    42.0          45.0       45.0       85.0
# Goodmayes                  35.0          50.0       45.5       67.0
# Southall                   42.0          33.0       35.0       80.0
# Hayes & Harlington         45.0          40.0       40.0       78.0
# Heathrow Central           52.0          60.0       59.5       89.0
# Tottenham Court Road      146.0          90.0      125.0      240.0
# Ealing Broadway            57.0          46.0       50.0       90.0
# Liverpool Street          104.5          98.0      100.0      163.0
# Bond Street               206.0         145.0      186.0      320.0
# Forest Gate                39.0          37.0       37.0       60.0
# Abbey Wood                 40.0          40.0       40.0       60.0
# Custom House               80.0          75.0       75.0      120.0
# Canary Wharf               80.0          60.0       68.0      120.0
# Harold Wood               117.0          40.0       49.5      172.5
# West Ealing                60.0          50.0       50.0       86.5
# Chadwell Heath             38.5          46.0       40.0       55.0
# West Drayton               49.0          42.5       47.5       70.0
# Ilford                     61.0          35.0       50.0       85.0
# Paddington                114.0         109.0      110.0      154.0
# Maryland                   50.0          45.0       48.0       66.0
# Woolwich                   60.0          50.0       50.0       78.0
# Whitechapel                60.0          70.0       65.0       78.0
# Stratford                  75.0          55.0       60.0       97.0
# Farringdon                115.0          92.0      100.0      147.0
# Acton Main Line            55.5          60.0       59.0       66.0
# Romford                    73.0          55.0       60.0       81.5
# Manor Park                 43.0          41.5       43.0       47.5
# Heathrow T4                36.0          43.0       40.0       39.0
# Seven Kings                55.0          40.0       49.0       59.0
# Gidea Park                 35.0          54.5       40.0       36.0
#
#                       R_1K_2K_2022  R_2K_2022  diff_1K  diff_1K_2K  diff_2K
# STATION_NA
# Hanwell                       72.5       80.0    1.024       0.611    0.778
# Goodmayes                     48.0       60.0    0.914      -0.040    0.319
# Southall                      65.0       72.0    0.905       0.970    1.057
# Hayes & Harlington            57.0       70.0    0.733       0.425    0.750
# Heathrow Central             111.0      105.5    0.712       0.850    0.773
# Tottenham Court Road         125.0      192.0    0.644       0.389    0.536
# Ealing Broadway               78.0       86.0    0.579       0.696    0.720
# Liverpool Street             134.0      140.0    0.560       0.367    0.400
# Bond Street                  242.0      288.0    0.553       0.669    0.548
# Forest Gate                   58.0       59.0    0.538       0.568    0.595
# Abbey Wood                    59.0       60.0    0.500       0.475    0.500
# Custom House                  99.5      105.0    0.500       0.327    0.400
# Canary Wharf                  75.0       85.0    0.500       0.250    0.250
# Harold Wood                   80.0      145.0    0.474       1.000    1.929
# West Ealing                   55.0       65.0    0.442       0.100    0.300
# Chadwell Heath                57.0       57.0    0.429       0.239    0.425
# West Drayton                  77.0       70.0    0.429       0.812    0.474
# Ilford                        55.0       65.0    0.393       0.571    0.300
# Paddington                   150.0      150.0    0.351       0.376    0.364
# Maryland                      60.0       64.0    0.320       0.333    0.333
# Woolwich                      74.0       75.0    0.300       0.480    0.500
# Whitechapel                   85.0       80.0    0.300       0.214    0.231
# Stratford                     80.0       85.0    0.293       0.455    0.417
# Farringdon                   125.0      134.0    0.278       0.359    0.340
# Acton Main Line               75.5       73.0    0.189       0.258    0.237
# Romford                       65.0       65.0    0.116       0.182    0.083
# Manor Park                    50.0       49.0    0.105       0.205    0.140
# Heathrow T4                  125.0       75.0    0.083       1.907    0.875
# Seven Kings                   59.0       59.0    0.073       0.475    0.204
# Gidea Park                    73.0       50.0    0.029       0.339    0.250

# %% [markdown]
# #### Ploting results

# %% [markdown]
# ##### Color according to connections to other stations

# %%
#Data for future color sensitive bar plot
station_color = results_2020_2022_total['diff_1K'].sort_values(ascending=False)
station_color_df = station_color.to_frame('diff_1K')
station_color_df = station_color_df.join(stations.set_index('STATION_NA'))
station_color_df['pink'] = station_color_df['con'].apply(lambda x: 'xkcd:purple' if x == 'Mono' else 'xkcd:grey')
pink_list = station_color_df["pink"].values.tolist()
pink_list.reverse()

# %%
#Ploting
results_2020_2022_total['diff_1K'].sort_values(ascending=True).plot(kind='barh',sort_columns=True,figsize=(5,8),in_layout=True, color=pink_list)
plt.xlabel('Variation percentage')
plt.ylabel('Station',rotation = 0)
plt.legend(['Mono connection', 'Multiple', 'C', 'D'], loc='center right', title='Not connected to other lines')
plt.savefig("Price_median_var_1k.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
results_2020_2022_total['diff_1K'].sort_values(ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in median price for 1km radius by station',figsize=(5,8),in_layout=True)
plt.savefig("Price_median_var_1k.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
results_2020_2022_total['diff_1K_2K'].sort_values(ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in median price for 1-2 km radius by station',figsize=(5,8),in_layout=True)
plt.savefig("Price_median_var_1k_2k.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
results_2020_2022_total['diff_2K'].sort_values(ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in median price for 2km radius by station',figsize=(5,8),in_layout=True)
plt.savefig("Price_median_var_2k.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
fig, ax = plt.subplots()
results_2020_2022_total[['diff_1K','diff_1K_2K','diff_2K']].sort_values('diff_1K',ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in median price by radius by station',figsize=(5,8),in_layout=True,ax=ax)
ax.legend(["1km radius", "1-2km radius","2km radius"])

# %% [markdown]
# ### Number of listings results by stations

# %%
# 2020
# Grouping count of listings in 1 km radius by stations
count_2020_r_1k = geo_air_2020_js[geo_air_2020_js.dist_to_s<1000].groupby('STATION_NA')['id'].agg('count').sort_values(ascending = False)
count_2020_r_1k.head()
# Out:
# STATION_NA
# Paddington              2127
# Whitechapel             1973
# Tottenham Court Road    1934
# Farringdon               996
# Bond Street              976
# Name: id, dtype: int64

# %%
# Grouping count of listings in 2 km radius by stations
count_2020_r_2k = geo_air_2020_js[geo_air_2020_js.dist_to_s<2000].groupby('STATION_NA')['id'].agg('count').sort_values(ascending = False)
count_2020_r_2k.head()
# Out:
# STATION_NA
# Paddington              4877
# Whitechapel             4202
# Tottenham Court Road    2907
# Farringdon              2426
# Liverpool Street        2034
# Name: id, dtype: int64

# %%
# Grouping count of listings in 1-2 km radius by stations
count_2020_r_1k_2k = geo_air_2020_js[(geo_air_2020.dist_to_s<2000) & (geo_air_2020.dist_to_s>1000)].groupby('STATION_NA')['id'].agg('count').sort_values(ascending = False)
count_2020_r_1k_2k.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:1428: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# STATION_NA
# Paddington          2750
# Whitechapel         2229
# Farringdon          1430
# Liverpool Street    1360
# Canary Wharf        1095
# Name: id, dtype: int64

# %%
# 2022
# Grouping count of listings in 1 km radius by stations
count_2022_r_1k = geo_air_2022_js[geo_air_2022_js.dist_to_s<1000].groupby('STATION_NA')['id'].agg('count').sort_values(ascending = False)
count_2022_r_1k.head()
# Out:
# STATION_NA
# Paddington              2192
# Tottenham Court Road    1696
# Whitechapel             1554
# Bond Street              920
# Farringdon               775
# Name: id, dtype: int64

# %%
# Grouping count of listings in 2 km radius by stations
count_2022_r_2k = geo_air_2022_js[geo_air_2022_js.dist_to_s<2000].groupby('STATION_NA')['id'].agg('count').sort_values(ascending = False)
count_2022_r_2k.head()
# Out:
# STATION_NA
# Paddington              4503
# Whitechapel             3490
# Tottenham Court Road    2611
# Farringdon              2133
# Liverpool Street        1851
# Name: id, dtype: int64

# %%
# Grouping count of listings in 1-2 km radius by stations
count_2022_r_1k_2k = geo_air_2022_js[(geo_air_2022.dist_to_s<2000) & (geo_air_2022.dist_to_s>1000)].groupby('STATION_NA')['id'].agg('count').sort_values(ascending = False)
count_2022_r_1k_2k.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:1428: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# STATION_NA
# Paddington          2311
# Whitechapel         1936
# Farringdon          1358
# Liverpool Street    1213
# Canary Wharf         989
# Name: id, dtype: int64

# %% [markdown]
# #### Merging 2020 listings results

# %%
# Merging 1k with 1-2km count of listings
count_2020 = pd.merge(count_2020_r_1k, count_2020_r_1k_2k, right_index = True, left_index = True)
count_2020
# Out:
#                       id_x  id_y
# STATION_NA
# Paddington            2127  2750
# Whitechapel           1973  2229
# Tottenham Court Road  1934   973
# Farringdon             996  1430
# Bond Street            976   548
# Canary Wharf           707  1095
# Liverpool Street       674  1360
# Custom House           284   440
# Stratford              257   642
# Acton Main Line        252   471
# Maryland               230   239
# Woolwich               212   284
# Ealing Broadway        157   151
# Forest Gate            153   154
# West Ealing            130    93
# West Drayton           102    42
# Ilford                  88    68
# Abbey Wood              81   113
# Manor Park              76    44
# Hanwell                 70    54
# Romford                 60    27
# Chadwell Heath          44    57
# Seven Kings             43    64
# Hayes & Harlington      42    31
# Southall                31    38
# Goodmayes               28    28
# Heathrow T4             22    26
# Harold Wood             19    29
# Gidea Park              15    10
# Heathrow Central         1    55

# %%
# Renaming merged columns
count_2020.rename(columns={'id_x': 'R_1K_2020', 'id_y': 'R_1K_2K_2020'}, inplace=True)
count_2020
# Out:
#                       R_1K_2020  R_1K_2K_2020
# STATION_NA
# Paddington                 2127          2750
# Whitechapel                1973          2229
# Tottenham Court Road       1934           973
# Farringdon                  996          1430
# Bond Street                 976           548
# Canary Wharf                707          1095
# Liverpool Street            674          1360
# Custom House                284           440
# Stratford                   257           642
# Acton Main Line             252           471
# Maryland                    230           239
# Woolwich                    212           284
# Ealing Broadway             157           151
# Forest Gate                 153           154
# West Ealing                 130            93
# West Drayton                102            42
# Ilford                       88            68
# Abbey Wood                   81           113
# Manor Park                   76            44
# Hanwell                      70            54
# Romford                      60            27
# Chadwell Heath               44            57
# Seven Kings                  43            64
# Hayes & Harlington           42            31
# Southall                     31            38
# Goodmayes                    28            28
# Heathrow T4                  22            26
# Harold Wood                  19            29
# Gidea Park                   15            10
# Heathrow Central              1            55

# %%
# Merging previous results with 2km listings counts
count_2020_total = pd.merge(count_2020, count_2020_r_2k, right_index = True, left_index = True)
count_2020_total
# Out:
#                       R_1K_2020  R_1K_2K_2020    id
# STATION_NA
# Paddington                 2127          2750  4877
# Whitechapel                1973          2229  4202
# Tottenham Court Road       1934           973  2907
# Farringdon                  996          1430  2426
# Bond Street                 976           548  1524
# Canary Wharf                707          1095  1802
# Liverpool Street            674          1360  2034
# Custom House                284           440   724
# Stratford                   257           642   899
# Acton Main Line             252           471   723
# Maryland                    230           239   469
# Woolwich                    212           284   496
# Ealing Broadway             157           151   308
# Forest Gate                 153           154   307
# West Ealing                 130            93   223
# West Drayton                102            42   144
# Ilford                       88            68   156
# Abbey Wood                   81           113   194
# Manor Park                   76            44   120
# Hanwell                      70            54   124
# Romford                      60            27    87
# Chadwell Heath               44            57   101
# Seven Kings                  43            64   107
# Hayes & Harlington           42            31    73
# Southall                     31            38    69
# Goodmayes                    28            28    56
# Heathrow T4                  22            26    48
# Harold Wood                  19            29    48
# Gidea Park                   15            10    25
# Heathrow Central              1            55    56

# %%
# Renaming 2km column
count_2020_total.rename(columns={'id': 'R_2K_2020'}, inplace=True)
count_2020_total
# Out:
#                       R_1K_2020  R_1K_2K_2020  R_2K_2020
# STATION_NA
# Paddington                 2127          2750       4877
# Whitechapel                1973          2229       4202
# Tottenham Court Road       1934           973       2907
# Farringdon                  996          1430       2426
# Bond Street                 976           548       1524
# Canary Wharf                707          1095       1802
# Liverpool Street            674          1360       2034
# Custom House                284           440        724
# Stratford                   257           642        899
# Acton Main Line             252           471        723
# Maryland                    230           239        469
# Woolwich                    212           284        496
# Ealing Broadway             157           151        308
# Forest Gate                 153           154        307
# West Ealing                 130            93        223
# West Drayton                102            42        144
# Ilford                       88            68        156
# Abbey Wood                   81           113        194
# Manor Park                   76            44        120
# Hanwell                      70            54        124
# Romford                      60            27         87
# Chadwell Heath               44            57        101
# Seven Kings                  43            64        107
# Hayes & Harlington           42            31         73
# Southall                     31            38         69
# Goodmayes                    28            28         56
# Heathrow T4                  22            26         48
# Harold Wood                  19            29         48
# Gidea Park                   15            10         25
# Heathrow Central              1            55         56

# %% [markdown]
# #### Merging 2022 results

# %%
# Merging 1k with 1-2km count of listings
count_2022 = pd.merge(count_2022_r_1k, count_2022_r_1k_2k, right_index = True, left_index = True)
count_2022
# Out:
#                       id_x  id_y
# STATION_NA
# Paddington            2192  2311
# Tottenham Court Road  1696   915
# Whitechapel           1554  1936
# Bond Street            920   531
# Farringdon             775  1358
# Canary Wharf           638   989
# Liverpool Street       638  1213
# Custom House           287   442
# Woolwich               266   267
# Acton Main Line        263   444
# Stratford              252   616
# Maryland               200   212
# Ealing Broadway        165   181
# West Ealing            130    85
# Forest Gate            121   119
# Ilford                 102    74
# West Drayton            91    44
# Hanwell                 77    46
# Abbey Wood              73   100
# Romford                 70    49
# Manor Park              60    51
# Hayes & Harlington      56    35
# Chadwell Heath          50    61
# Southall                45    51
# Goodmayes               36    17
# Heathrow T4             26    47
# Seven Kings             13    61
# Gidea Park              11    10
# Harold Wood             10    27
# Iver                     7     3
# Heathrow Central         1    73

# %%
# Renaming columns
count_2022.rename(columns={'id_x': 'R_1K_2022', 'id_y': 'R_1K_2K_2022'}, inplace=True)
count_2022
# Out:
#                       R_1K_2022  R_1K_2K_2022
# STATION_NA
# Paddington                 2192          2311
# Tottenham Court Road       1696           915
# Whitechapel                1554          1936
# Bond Street                 920           531
# Farringdon                  775          1358
# Canary Wharf                638           989
# Liverpool Street            638          1213
# Custom House                287           442
# Woolwich                    266           267
# Acton Main Line             263           444
# Stratford                   252           616
# Maryland                    200           212
# Ealing Broadway             165           181
# West Ealing                 130            85
# Forest Gate                 121           119
# Ilford                      102            74
# West Drayton                 91            44
# Hanwell                      77            46
# Abbey Wood                   73           100
# Romford                      70            49
# Manor Park                   60            51
# Hayes & Harlington           56            35
# Chadwell Heath               50            61
# Southall                     45            51
# Goodmayes                    36            17
# Heathrow T4                  26            47
# Seven Kings                  13            61
# Gidea Park                   11            10
# Harold Wood                  10            27
# Iver                          7             3
# Heathrow Central              1            73

# %%
# Merging previous results with 2km listings counts
count_2022_total = pd.merge(count_2022, count_2022_r_2k, right_index = True, left_index = True)
count_2022_total
# Out:
#                       R_1K_2022  R_1K_2K_2022    id
# STATION_NA
# Paddington                 2192          2311  4503
# Tottenham Court Road       1696           915  2611
# Whitechapel                1554          1936  3490
# Bond Street                 920           531  1451
# Farringdon                  775          1358  2133
# Canary Wharf                638           989  1627
# Liverpool Street            638          1213  1851
# Custom House                287           442   729
# Woolwich                    266           267   533
# Acton Main Line             263           444   707
# Stratford                   252           616   868
# Maryland                    200           212   412
# Ealing Broadway             165           181   346
# West Ealing                 130            85   215
# Forest Gate                 121           119   240
# Ilford                      102            74   176
# West Drayton                 91            44   135
# Hanwell                      77            46   123
# Abbey Wood                   73           100   173
# Romford                      70            49   119
# Manor Park                   60            51   111
# Hayes & Harlington           56            35    91
# Chadwell Heath               50            61   111
# Southall                     45            51    96
# Goodmayes                    36            17    53
# Heathrow T4                  26            47    73
# Seven Kings                  13            61    74
# Gidea Park                   11            10    21
# Harold Wood                  10            27    37
# Iver                          7             3    10
# Heathrow Central              1            73    74

# %%
# Renaming 2km column
count_2022_total.rename(columns={'id': 'R_2K_2022'}, inplace=True)
count_2022_total
# Out:
#                       R_1K_2022  R_1K_2K_2022  R_2K_2022
# STATION_NA
# Paddington                 2192          2311       4503
# Tottenham Court Road       1696           915       2611
# Whitechapel                1554          1936       3490
# Bond Street                 920           531       1451
# Farringdon                  775          1358       2133
# Canary Wharf                638           989       1627
# Liverpool Street            638          1213       1851
# Custom House                287           442        729
# Woolwich                    266           267        533
# Acton Main Line             263           444        707
# Stratford                   252           616        868
# Maryland                    200           212        412
# Ealing Broadway             165           181        346
# West Ealing                 130            85        215
# Forest Gate                 121           119        240
# Ilford                      102            74        176
# West Drayton                 91            44        135
# Hanwell                      77            46        123
# Abbey Wood                   73           100        173
# Romford                      70            49        119
# Manor Park                   60            51        111
# Hayes & Harlington           56            35         91
# Chadwell Heath               50            61        111
# Southall                     45            51         96
# Goodmayes                    36            17         53
# Heathrow T4                  26            47         73
# Seven Kings                  13            61         74
# Gidea Park                   11            10         21
# Harold Wood                  10            27         37
# Iver                          7             3         10
# Heathrow Central              1            73         74

# %% [markdown]
# #### Merging 2020 and 2022 listings results

# %%
# Merging 2020 and 2022 count dfs
count_2020_2022_total = pd.merge(count_2020_total, count_2022_total, right_index = True, left_index = True)
count_2020_2022_total
# Out:
#                       R_1K_2020  R_1K_2K_2020  R_2K_2020  R_1K_2022  \
# STATION_NA
# Paddington                 2127          2750       4877       2192
# Whitechapel                1973          2229       4202       1554
# Tottenham Court Road       1934           973       2907       1696
# Farringdon                  996          1430       2426        775
# Bond Street                 976           548       1524        920
# Canary Wharf                707          1095       1802        638
# Liverpool Street            674          1360       2034        638
# Custom House                284           440        724        287
# Stratford                   257           642        899        252
# Acton Main Line             252           471        723        263
# Maryland                    230           239        469        200
# Woolwich                    212           284        496        266
# Ealing Broadway             157           151        308        165
# Forest Gate                 153           154        307        121
# West Ealing                 130            93        223        130
# West Drayton                102            42        144         91
# Ilford                       88            68        156        102
# Abbey Wood                   81           113        194         73
# Manor Park                   76            44        120         60
# Hanwell                      70            54        124         77
# Romford                      60            27         87         70
# Chadwell Heath               44            57        101         50
# Seven Kings                  43            64        107         13
# Hayes & Harlington           42            31         73         56
# Southall                     31            38         69         45
# Goodmayes                    28            28         56         36
# Heathrow T4                  22            26         48         26
# Harold Wood                  19            29         48         10
# Gidea Park                   15            10         25         11
# Heathrow Central              1            55         56          1
#
#                       R_1K_2K_2022  R_2K_2022
# STATION_NA
# Paddington                    2311       4503
# Whitechapel                   1936       3490
# Tottenham Court Road           915       2611
# Farringdon                    1358       2133
# Bond Street                    531       1451
# Canary Wharf                   989       1627
# Liverpool Street              1213       1851
# Custom House                   442        729
# Stratford                      616        868
# Acton Main Line                444        707
# Maryland                       212        412
# Woolwich                       267        533
# Ealing Broadway                181        346
# Forest Gate                    119        240
# West Ealing                     85        215
# West Drayton                    44        135
# Ilford                          74        176
# Abbey Wood                     100        173
# Manor Park                      51        111
# Hanwell                         46        123
# Romford                         49        119
# Chadwell Heath                  61        111
# Seven Kings                     61         74
# Hayes & Harlington              35         91
# Southall                        51         96
# Goodmayes                       17         53
# Heathrow T4                     47         73
# Harold Wood                     27         37
# Gidea Park                      10         21
# Heathrow Central                73         74

# %%
# Calculating percentage variation for each radius
count_2020_2022_total['diff_1K'] = (count_2020_2022_total['R_1K_2022']-count_2020_2022_total['R_1K_2020'])/count_2020_2022_total['R_1K_2020']
count_2020_2022_total['diff_1K_2K'] = (count_2020_2022_total['R_1K_2K_2022']-count_2020_2022_total['R_1K_2K_2020'])/count_2020_2022_total['R_1K_2K_2020']
count_2020_2022_total['diff_2K'] = (count_2020_2022_total['R_2K_2022']-count_2020_2022_total['R_2K_2020'])/count_2020_2022_total['R_2K_2020']

# Assigning percentage format
count_2020_2022_total.style.format({
    'diff_1K': '{:,.2%}'.format,
    'diff_1K_2K': '{:,.2%}'.format,
    'diff_2K': '{:,.2%}'.format,
})

count_2020_2022_total
# Out:
#                       R_1K_2020  R_1K_2K_2020  R_2K_2020  R_1K_2022  \
# STATION_NA
# Paddington                 2127          2750       4877       2192
# Whitechapel                1973          2229       4202       1554
# Tottenham Court Road       1934           973       2907       1696
# Farringdon                  996          1430       2426        775
# Bond Street                 976           548       1524        920
# Canary Wharf                707          1095       1802        638
# Liverpool Street            674          1360       2034        638
# Custom House                284           440        724        287
# Stratford                   257           642        899        252
# Acton Main Line             252           471        723        263
# Maryland                    230           239        469        200
# Woolwich                    212           284        496        266
# Ealing Broadway             157           151        308        165
# Forest Gate                 153           154        307        121
# West Ealing                 130            93        223        130
# West Drayton                102            42        144         91
# Ilford                       88            68        156        102
# Abbey Wood                   81           113        194         73
# Manor Park                   76            44        120         60
# Hanwell                      70            54        124         77
# Romford                      60            27         87         70
# Chadwell Heath               44            57        101         50
# Seven Kings                  43            64        107         13
# Hayes & Harlington           42            31         73         56
# Southall                     31            38         69         45
# Goodmayes                    28            28         56         36
# Heathrow T4                  22            26         48         26
# Harold Wood                  19            29         48         10
# Gidea Park                   15            10         25         11
# Heathrow Central              1            55         56          1
#
#                       R_1K_2K_2022  R_2K_2022   diff_1K  diff_1K_2K   diff_2K
# STATION_NA
# Paddington                    2311       4503  0.030559   -0.159636 -0.076686
# Whitechapel                   1936       3490 -0.212367   -0.131449 -0.169443
# Tottenham Court Road           915       2611 -0.123061   -0.059609 -0.101823
# Farringdon                    1358       2133 -0.221888   -0.050350 -0.120775
# Bond Street                    531       1451 -0.057377   -0.031022 -0.047900
# Canary Wharf                   989       1627 -0.097595   -0.096804 -0.097114
# Liverpool Street              1213       1851 -0.053412   -0.108088 -0.089971
# Custom House                   442        729  0.010563    0.004545  0.006906
# Stratford                      616        868 -0.019455   -0.040498 -0.034483
# Acton Main Line                444        707  0.043651   -0.057325 -0.022130
# Maryland                       212        412 -0.130435   -0.112971 -0.121535
# Woolwich                       267        533  0.254717   -0.059859  0.074597
# Ealing Broadway                181        346  0.050955    0.198675  0.123377
# Forest Gate                    119        240 -0.209150   -0.227273 -0.218241
# West Ealing                     85        215  0.000000   -0.086022 -0.035874
# West Drayton                    44        135 -0.107843    0.047619 -0.062500
# Ilford                          74        176  0.159091    0.088235  0.128205
# Abbey Wood                     100        173 -0.098765   -0.115044 -0.108247
# Manor Park                      51        111 -0.210526    0.159091 -0.075000
# Hanwell                         46        123  0.100000   -0.148148 -0.008065
# Romford                         49        119  0.166667    0.814815  0.367816
# Chadwell Heath                  61        111  0.136364    0.070175  0.099010
# Seven Kings                     61         74 -0.697674   -0.046875 -0.308411
# Hayes & Harlington              35         91  0.333333    0.129032  0.246575
# Southall                        51         96  0.451613    0.342105  0.391304
# Goodmayes                       17         53  0.285714   -0.392857 -0.053571
# Heathrow T4                     47         73  0.181818    0.807692  0.520833
# Harold Wood                     27         37 -0.473684   -0.068966 -0.229167
# Gidea Park                      10         21 -0.266667    0.000000 -0.160000
# Heathrow Central                73         74  0.000000    0.327273  0.321429

# %% [markdown]
# #### Ploting listings results

# %%
count_2020_2022_total['diff_1K'].sort_values(ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in number of listings for 1km radius by station',figsize=(5,8),in_layout=True)
plt.savefig("Listings_var_1k.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
count_2020_2022_total['diff_1K_2K'].sort_values(ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in number of listings for 1-2 km radius by station',figsize=(5,8),in_layout=True)
plt.savefig("Listings_var_1k_2k.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
count_2020_2022_total['diff_2K'].sort_values(ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in number of listings for 2km radius by station',figsize=(5,8),in_layout=True)
plt.savefig("Listings_var_2k.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
fig, ax = plt.subplots()
count_2020_2022_total[['diff_1K','diff_1K_2K','diff_2K']].sort_values('diff_1K',ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in median price by radius by station',figsize=(5,8),in_layout=True,ax=ax)
ax.legend(["1km radius", "1-2km radius","2km radius"])

# %% [markdown]
# ### Final merge

# %%
# Meging counts and median price df
final_2020_2022 = pd.merge(results_2020_2022_total, count_2020_2022_total, right_index = True, left_index = True, suffixes= ('_m','_c'))
final_2020_2022.sort_values('diff_1K_2K_m',ascending=False)
# Out:
#                       R_1K_2020_m  R_1K_2K_2020_m  R_2K_2020_m  R_1K_2022_m  \
# STATION_NA
# Heathrow T4                  36.0            43.0         40.0         39.0
# Harold Wood                 117.0            40.0         49.5        172.5
# Southall                     42.0            33.0         35.0         80.0
# Heathrow Central             52.0            60.0         59.5         89.0
# West Drayton                 49.0            42.5         47.5         70.0
# Ealing Broadway              57.0            46.0         50.0         90.0
# Bond Street                 206.0           145.0        186.0        320.0
# Hanwell                      42.0            45.0         45.0         85.0
# Ilford                       61.0            35.0         50.0         85.0
# Forest Gate                  39.0            37.0         37.0         60.0
# Woolwich                     60.0            50.0         50.0         78.0
# Seven Kings                  55.0            40.0         49.0         59.0
# Abbey Wood                   40.0            40.0         40.0         60.0
# Stratford                    75.0            55.0         60.0         97.0
# Hayes & Harlington           45.0            40.0         40.0         78.0
# Tottenham Court Road        146.0            90.0        125.0        240.0
# Paddington                  114.0           109.0        110.0        154.0
# Liverpool Street            104.5            98.0        100.0        163.0
# Farringdon                  115.0            92.0        100.0        147.0
# Gidea Park                   35.0            54.5         40.0         36.0
# Maryland                     50.0            45.0         48.0         66.0
# Custom House                 80.0            75.0         75.0        120.0
# Acton Main Line              55.5            60.0         59.0         66.0
# Canary Wharf                 80.0            60.0         68.0        120.0
# Chadwell Heath               38.5            46.0         40.0         55.0
# Whitechapel                  60.0            70.0         65.0         78.0
# Manor Park                   43.0            41.5         43.0         47.5
# Romford                      73.0            55.0         60.0         81.5
# West Ealing                  60.0            50.0         50.0         86.5
# Goodmayes                    35.0            50.0         45.5         67.0
#
#                       R_1K_2K_2022_m  R_2K_2022_m  diff_1K_m  diff_1K_2K_m  \
# STATION_NA
# Heathrow T4                    125.0         75.0      0.083         1.907
# Harold Wood                     80.0        145.0      0.474         1.000
# Southall                        65.0         72.0      0.905         0.970
# Heathrow Central               111.0        105.5      0.712         0.850
# West Drayton                    77.0         70.0      0.429         0.812
# Ealing Broadway                 78.0         86.0      0.579         0.696
# Bond Street                    242.0        288.0      0.553         0.669
# Hanwell                         72.5         80.0      1.024         0.611
# Ilford                          55.0         65.0      0.393         0.571
# Forest Gate                     58.0         59.0      0.538         0.568
# Woolwich                        74.0         75.0      0.300         0.480
# Seven Kings                     59.0         59.0      0.073         0.475
# Abbey Wood                      59.0         60.0      0.500         0.475
# Stratford                       80.0         85.0      0.293         0.455
# Hayes & Harlington              57.0         70.0      0.733         0.425
# Tottenham Court Road           125.0        192.0      0.644         0.389
# Paddington                     150.0        150.0      0.351         0.376
# Liverpool Street               134.0        140.0      0.560         0.367
# Farringdon                     125.0        134.0      0.278         0.359
# Gidea Park                      73.0         50.0      0.029         0.339
# Maryland                        60.0         64.0      0.320         0.333
# Custom House                    99.5        105.0      0.500         0.327
# Acton Main Line                 75.5         73.0      0.189         0.258
# Canary Wharf                    75.0         85.0      0.500         0.250
# Chadwell Heath                  57.0         57.0      0.429         0.239
# Whitechapel                     85.0         80.0      0.300         0.214
# Manor Park                      50.0         49.0      0.105         0.205
# Romford                         65.0         65.0      0.116         0.182
# West Ealing                     55.0         65.0      0.442         0.100
# Goodmayes                       48.0         60.0      0.914        -0.040
#
#                       diff_2K_m  R_1K_2020_c  R_1K_2K_2020_c  R_2K_2020_c  \
# STATION_NA
# Heathrow T4               0.875           22              26           48
# Harold Wood               1.929           19              29           48
# Southall                  1.057           31              38           69
# Heathrow Central          0.773            1              55           56
# West Drayton              0.474          102              42          144
# Ealing Broadway           0.720          157             151          308
# Bond Street               0.548          976             548         1524
# Hanwell                   0.778           70              54          124
# Ilford                    0.300           88              68          156
# Forest Gate               0.595          153             154          307
# Woolwich                  0.500          212             284          496
# Seven Kings               0.204           43              64          107
# Abbey Wood                0.500           81             113          194
# Stratford                 0.417          257             642          899
# Hayes & Harlington        0.750           42              31           73
# Tottenham Court Road      0.536         1934             973         2907
# Paddington                0.364         2127            2750         4877
# Liverpool Street          0.400          674            1360         2034
# Farringdon                0.340          996            1430         2426
# Gidea Park                0.250           15              10           25
# Maryland                  0.333          230             239          469
# Custom House              0.400          284             440          724
# Acton Main Line           0.237          252             471          723
# Canary Wharf              0.250          707            1095         1802
# Chadwell Heath            0.425           44              57          101
# Whitechapel               0.231         1973            2229         4202
# Manor Park                0.140           76              44          120
# Romford                   0.083           60              27           87
# West Ealing               0.300          130              93          223
# Goodmayes                 0.319           28              28           56
#
#                       R_1K_2022_c  R_1K_2K_2022_c  R_2K_2022_c  diff_1K_c  \
# STATION_NA
# Heathrow T4                    26              47           73   0.181818
# Harold Wood                    10              27           37  -0.473684
# Southall                       45              51           96   0.451613
# Heathrow Central                1              73           74   0.000000
# West Drayton                   91              44          135  -0.107843
# Ealing Broadway               165             181          346   0.050955
# Bond Street                   920             531         1451  -0.057377
# Hanwell                        77              46          123   0.100000
# Ilford                        102              74          176   0.159091
# Forest Gate                   121             119          240  -0.209150
# Woolwich                      266             267          533   0.254717
# Seven Kings                    13              61           74  -0.697674
# Abbey Wood                     73             100          173  -0.098765
# Stratford                     252             616          868  -0.019455
# Hayes & Harlington             56              35           91   0.333333
# Tottenham Court Road         1696             915         2611  -0.123061
# Paddington                   2192            2311         4503   0.030559
# Liverpool Street              638            1213         1851  -0.053412
# Farringdon                    775            1358         2133  -0.221888
# Gidea Park                     11              10           21  -0.266667
# Maryland                      200             212          412  -0.130435
# Custom House                  287             442          729   0.010563
# Acton Main Line               263             444          707   0.043651
# Canary Wharf                  638             989         1627  -0.097595
# Chadwell Heath                 50              61          111   0.136364
# Whitechapel                  1554            1936         3490  -0.212367
# Manor Park                     60              51          111  -0.210526
# Romford                        70              49          119   0.166667
# West Ealing                   130              85          215   0.000000
# Goodmayes                      36              17           53   0.285714
#
#                       diff_1K_2K_c  diff_2K_c
# STATION_NA
# Heathrow T4               0.807692   0.520833
# Harold Wood              -0.068966  -0.229167
# Southall                  0.342105   0.391304
# Heathrow Central          0.327273   0.321429
# West Drayton              0.047619  -0.062500
# Ealing Broadway           0.198675   0.123377
# Bond Street              -0.031022  -0.047900
# Hanwell                  -0.148148  -0.008065
# Ilford                    0.088235   0.128205
# Forest Gate              -0.227273  -0.218241
# Woolwich                 -0.059859   0.074597
# Seven Kings              -0.046875  -0.308411
# Abbey Wood               -0.115044  -0.108247
# Stratford                -0.040498  -0.034483
# Hayes & Harlington        0.129032   0.246575
# Tottenham Court Road     -0.059609  -0.101823
# Paddington               -0.159636  -0.076686
# Liverpool Street         -0.108088  -0.089971
# Farringdon               -0.050350  -0.120775
# Gidea Park                0.000000  -0.160000
# Maryland                 -0.112971  -0.121535
# Custom House              0.004545   0.006906
# Acton Main Line          -0.057325  -0.022130
# Canary Wharf             -0.096804  -0.097114
# Chadwell Heath            0.070175   0.099010
# Whitechapel              -0.131449  -0.169443
# Manor Park                0.159091  -0.075000
# Romford                   0.814815   0.367816
# West Ealing              -0.086022  -0.035874
# Goodmayes                -0.392857  -0.053571

# %%
fig, ax = plt.subplots()
final_2020_2022[['diff_1K_m','diff_1K_2K_m']].sort_values('diff_1K_m',ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in median price by radius by station',figsize=(5,8),in_layout=True,ax=ax)
ax.legend(["1 km radius", "1-2 km radius"])
plt.savefig("Price_median_var_1k_1-2k.jpg",bbox_inches='tight',dpi=300)

# %%
fig, ax = plt.subplots()
final_2020_2022[['diff_1K_c','diff_2K_c']].sort_values('diff_1K_c',ascending=True).plot(kind='barh',sort_columns=True, title='Percentage 2022-2020 variation in number of listings by radius by station',figsize=(5,8),in_layout=True,ax=ax)
ax.legend(["1 km radius", "2 km radius"])

# %%
# Ad end

# %% [markdown]
# ## 7. Zone analysis for airbnb listing prices

# %% [markdown]
# ### Introduction
#
# In this section, the listings of Airbnb will be analyzed and grouped according to the fare zone of their location. After the spatial joint with the corresponding zona, the median prices and number of listings will be analyzed by grouping the data by each fare zone.

# %%
# Copy the raw data from London shape file
London = London_raw.copy()

# Change the CRS to EPSG 27700
London = London.to_crs('EPSG:27700')

# Plot the area
London.plot()
# Out:
# <AxesSubplot:>

# %%
# Copy the raw data
el_station = el_station_raw.copy()

# Plot the shape
el_station.plot()
# Out:
# <AxesSubplot:>

# %%
# Copy the raw data
el_track = el_track_raw.copy()

# Plot the shape
el_track.plot()
# Out:
# <AxesSubplot:>

# %%
# Check the crs for these shape files
print(f'The crs for London OA: \n {London.crs}')
print(f'\n The crs for Elizabeth Line stations: \n {el_station.crs}')
print(f'\n The crs for Elizabeth Line tracks: \n {el_track.crs}')
# Out:
# The crs for London OA:
#  EPSG:27700
#
#  The crs for Elizabeth Line stations:
#  epsg:27700
#
#  The crs for Elizabeth Line tracks:
#  epsg:27700

# %%
# Plot the stations on the map
# Create a figure and axis
fig, ax = plt.subplots(1,1, figsize=(25,10))

# Plot the OA London boundaries
London.to_crs('epsg:27700').plot(edgecolor='lightblue', facecolor='white', ax=ax)

# Plot the Elizabeth Line stations
el_station.to_crs('epsg:27700').plot(edgecolor='black', facecolor='white', ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Reset the row width
pd.reset_option('^display.', silent=True)

# %%
# Check the airbnb listings in 2022
airbnb_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67832 entries, 0 to 69350
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            67832 non-null  int64
#  1   listing_url                                   67832 non-null  object
#  2   scrape_id                                     67832 non-null  int64
#  3   last_scraped                                  67832 non-null  object
#  4   source                                        67832 non-null  object
#  5   name                                          67812 non-null  object
#  6   description                                   67832 non-null  object
#  7   neighborhood_overview                         39868 non-null  object
#  8   picture_url                                   67832 non-null  object
#  9   host_id                                       67832 non-null  int64
#  10  host_url                                      67832 non-null  object
#  11  host_name                                     67827 non-null  object
#  12  host_since                                    67827 non-null  object
#  13  host_location                                 55756 non-null  object
#  14  host_about                                    36322 non-null  object
#  15  host_response_time                            42105 non-null  object
#  16  host_response_rate                            42105 non-null  object
#  17  host_acceptance_rate                          44309 non-null  object
#  18  host_is_superhost                             67831 non-null  object
#  19  host_thumbnail_url                            67827 non-null  object
#  20  host_picture_url                              67827 non-null  object
#  21  host_neighbourhood                            42834 non-null  object
#  22  host_listings_count                           67827 non-null  float64
#  23  host_total_listings_count                     67827 non-null  float64
#  24  host_verifications                            67832 non-null  object
#  25  host_has_profile_pic                          67827 non-null  object
#  26  host_identity_verified                        67827 non-null  object
#  27  neighbourhood                                 39869 non-null  object
#  28  neighbourhood_cleansed                        67832 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      67832 non-null  float64
#  31  longitude                                     67832 non-null  float64
#  32  property_type                                 67832 non-null  object
#  33  room_type                                     67832 non-null  object
#  34  accommodates                                  67832 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                67722 non-null  object
#  37  bedrooms                                      64591 non-null  float64
#  38  beds                                          66741 non-null  float64
#  39  amenities                                     67832 non-null  object
#  40  price                                         67832 non-null  object
#  41  minimum_nights                                67832 non-null  int64
#  42  maximum_nights                                67832 non-null  int64
#  43  minimum_minimum_nights                        67831 non-null  float64
#  44  maximum_minimum_nights                        67831 non-null  float64
#  45  minimum_maximum_nights                        67831 non-null  float64
#  46  maximum_maximum_nights                        67831 non-null  float64
#  47  minimum_nights_avg_ntm                        67831 non-null  float64
#  48  maximum_nights_avg_ntm                        67831 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              67832 non-null  object
#  51  availability_30                               67832 non-null  int64
#  52  availability_60                               67832 non-null  int64
#  53  availability_90                               67832 non-null  int64
#  54  availability_365                              67832 non-null  int64
#  55  calendar_last_scraped                         67832 non-null  object
#  56  number_of_reviews                             67832 non-null  int64
#  57  number_of_reviews_ltm                         67832 non-null  int64
#  58  number_of_reviews_l30d                        67832 non-null  int64
#  59  first_review                                  51738 non-null  object
#  60  last_review                                   51738 non-null  object
#  61  review_scores_rating                          51738 non-null  float64
#  62  review_scores_accuracy                        50757 non-null  float64
#  63  review_scores_cleanliness                     50770 non-null  float64
#  64  review_scores_checkin                         50723 non-null  float64
#  65  review_scores_communication                   50756 non-null  float64
#  66  review_scores_location                        50725 non-null  float64
#  67  review_scores_value                           50722 non-null  float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              67832 non-null  object
#  70  calculated_host_listings_count                67832 non-null  int64
#  71  calculated_host_listings_count_entire_homes   67832 non-null  int64
#  72  calculated_host_listings_count_private_rooms  67832 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   67832 non-null  int64
#  74  reviews_per_month                             51738 non-null  float64
# dtypes: float64(24), int64(17), object(34)
# memory usage: 39.3+ MB

# %%
# Drop columns that are entirely null or None
airbnb_22 = airbnb_22.dropna(axis=1, how='all')

# %%
# Check the price data since it is object
airbnb_22.price
# Out:
# 0         $50.00
# 1         $75.00
# 2         $90.00
# 3         $55.00
# 4        $379.00
#           ...
# 69346     $55.00
# 69347    $201.00
# 69348    $246.00
# 69349    $250.00
# 69350    $134.00
# Name: price, Length: 67832, dtype: object

# %%
# Replace the unit and change it to numerical for further calculations
# Only process x if it is str
airbnb_22['price'] = airbnb_22['price'].apply(lambda x: float(re.sub(r'[$,]', '', x) if isinstance(x, str) else x)) 
airbnb_22.price
# Out:
# 0         50.0
# 1         75.0
# 2         90.0
# 3         55.0
# 4        379.0
#          ...
# 69346     55.0
# 69347    201.0
# 69348    246.0
# 69349    250.0
# 69350    134.0
# Name: price, Length: 67832, dtype: float64

# %%
# Extract the needed information
airbnb_22_price = airbnb_22.loc[:,['id', 'price', 'longitude', 'latitude']]
airbnb_22_price.head()
# Out:
#        id  price  longitude  latitude
# 0   13913   50.0   -0.11270  51.56861
# 1   15400   75.0   -0.16813  51.48780
# 2  284532   90.0   -0.07426  51.52851
# 3  106332   55.0   -0.05396  51.52874
# 4   17402  379.0   -0.14094  51.52195

# %%
# Make the airbnb 2022 data as point pattern
airbnb_22_point = gpd.GeoDataFrame(airbnb_22_price, 
      geometry=gpd.points_from_xy(airbnb_22_price.longitude, airbnb_22_price.latitude, crs='epsg:4326'))

# Change the CRS to EPSG 27700
airbnb_22_point = airbnb_22_point.to_crs('EPSG:27700')

# %%
# Check the data
airbnb_22_point.sample(n=10,random_state=100)
# Out:
#                        id   price  longitude   latitude  \
# 14578            15717701    40.0  -0.008000  51.499700
# 32663            31902270    85.0  -0.151610  51.574590
# 31214            30317505    36.0  -0.110710  51.423790
# 54344  546003436065611887    75.0  -0.064010  51.479570
# 56269  590494832845187220    60.0  -0.051230  51.532027
# 63948  675721740399637975   100.0  -0.053957  51.547701
# 28149            27095286    80.0  -0.200540  51.523990
# 54261  538251585285658710  1570.0  -0.208880  51.524770
# 55335  575893889457714372   100.0  -0.325170  51.507760
# 34118            33577680   350.0  -0.147660  51.516370
#
#                             geometry
# 14578  POINT (538365.535 179743.315)
# 32663  POINT (528187.656 187809.916)
# 31214  POINT (531454.582 171112.932)
# 54344  POINT (534537.299 177400.503)
# 56269  POINT (535269.375 183257.414)
# 63948  POINT (535033.849 184995.357)
# 28149  POINT (524935.552 182098.363)
# 54261  POINT (524354.877 182170.908)
# 55335  POINT (516331.128 180088.243)
# 34118  POINT (528625.309 181342.524)

# %%
# Check the column names
airbnb_22_point.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 67832 entries, 0 to 69350
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         67832 non-null  int64
#  1   price      67832 non-null  float64
#  2   longitude  67832 non-null  float64
#  3   latitude   67832 non-null  float64
#  4   geometry   67832 non-null  geometry
# dtypes: float64(3), geometry(1), int64(1)
# memory usage: 3.1 MB

# %%
# Plot the Airbnb listing points in London boundaries
# Create a figure and axis
fig, ax = plt.subplots(1,1, figsize=(25,10))

# Plot the OA London boundaries
London.to_crs(epsg=27700).plot(edgecolor='lightblue', facecolor='white', ax=ax)

# Plot the 2022 airbnb listing points and coloured by their price
airbnb_22_point.to_crs(epsg=27700).plot(column='price', cmap='viridis', alpha=0.25, markersize=1, ax=ax)
# Out:
# <AxesSubplot:>

# %%
zones = zones_raw.copy()
zones.head()
# Out:
#       OA11CD  Fare_Zone
# 0  E00000001          1
# 1  E00000003          1
# 2  E00000005          1
# 3  E00000007          1
# 4  E00000010          1

# %%
# Check the London boundaries
London.head()
# Out:
#       OA11CD   LSOA11CD   MSOA11CD  WD11CD_BF    WD11NM_BF    LAD11CD  \
# 0  E00023264  E01004612  E02000954  E05000626      Tooting  E09000032
# 1  E00003359  E01000692  E02000128  E05000111  Chislehurst  E09000006
# 2  E00023266  E01004615  E02000956  E05000626      Tooting  E09000032
# 3  E00020264  E01004027  E02000809  E05000548    Riverside  E09000028
# 4  E00023263  E01004613  E02000955  E05000626      Tooting  E09000032
#
#       LAD11NM    RGN11CD RGN11NM         LSOA11NM        MSOA11NM  USUALRES  \
# 0  Wandsworth  E12000007  London  Wandsworth 032C  Wandsworth 032       462
# 1     Bromley  E12000007  London     Bromley 002D     Bromley 002       269
# 2  Wandsworth  E12000007  London  Wandsworth 034B  Wandsworth 034       277
# 3   Southwark  E12000007  London   Southwark 003E   Southwark 003       415
# 4  Wandsworth  E12000007  London  Wandsworth 033D  Wandsworth 033       304
#
#    HHOLDRES  COMESTRES  POPDEN  HHOLDS  AVHHOLDSZ  \
# 0       459          3   115.2     143        3.2
# 1       259         10    36.7     133        1.9
# 2       277          0   183.4     133        2.1
# 3       415          0    96.1     191        2.2
# 4       304          0   165.2     131        2.3
#
#                                             geometry
# 0  POLYGON ((527635.452 171810.058, 527495.957 17...
# 1  POLYGON ((543581.516 171132.486, 543704.000 17...
# 2  POLYGON ((526613.539 171839.165, 526546.840 17...
# 3  POLYGON ((533563.521 179695.146, 533351.118 17...
# 4  POLYGON ((527822.000 172020.000, 527979.000 17...

# %%
# Left join the OA London boundaries and the fare zones
London_zones = London.merge(zones, on='OA11CD', how='left')

# Rename the new column to Zone
London_zones = London_zones.rename(columns={'Fare_Zone': 'Zone'})
London_zones.head()
# Out:
#       OA11CD   LSOA11CD   MSOA11CD  WD11CD_BF    WD11NM_BF    LAD11CD  \
# 0  E00023264  E01004612  E02000954  E05000626      Tooting  E09000032
# 1  E00003359  E01000692  E02000128  E05000111  Chislehurst  E09000006
# 2  E00023266  E01004615  E02000956  E05000626      Tooting  E09000032
# 3  E00020264  E01004027  E02000809  E05000548    Riverside  E09000028
# 4  E00023263  E01004613  E02000955  E05000626      Tooting  E09000032
#
#       LAD11NM    RGN11CD RGN11NM         LSOA11NM        MSOA11NM  USUALRES  \
# 0  Wandsworth  E12000007  London  Wandsworth 032C  Wandsworth 032       462
# 1     Bromley  E12000007  London     Bromley 002D     Bromley 002       269
# 2  Wandsworth  E12000007  London  Wandsworth 034B  Wandsworth 034       277
# 3   Southwark  E12000007  London   Southwark 003E   Southwark 003       415
# 4  Wandsworth  E12000007  London  Wandsworth 033D  Wandsworth 033       304
#
#    HHOLDRES  COMESTRES  POPDEN  HHOLDS  AVHHOLDSZ  \
# 0       459          3   115.2     143        3.2
# 1       259         10    36.7     133        1.9
# 2       277          0   183.4     133        2.1
# 3       415          0    96.1     191        2.2
# 4       304          0   165.2     131        2.3
#
#                                             geometry  Zone
# 0  POLYGON ((527635.452 171810.058, 527495.957 17...     3
# 1  POLYGON ((543581.516 171132.486, 543704.000 17...     4
# 2  POLYGON ((526613.539 171839.165, 526546.840 17...     3
# 3  POLYGON ((533563.521 179695.146, 533351.118 17...     1
# 4  POLYGON ((527822.000 172020.000, 527979.000 17...     3

# %%
# Join the airbnb listing points that are within the boundaries
London_zones_airbnb_22 = gpd.sjoin(airbnb_22_point,London_zones, how="left")

# %%
London_zones_airbnb_22.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 67832 entries, 0 to 69350
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           67832 non-null  int64
#  1   price        67832 non-null  float64
#  2   longitude    67832 non-null  float64
#  3   latitude     67832 non-null  float64
#  4   geometry     67832 non-null  geometry
#  5   index_right  67087 non-null  float64
#  6   OA11CD       67087 non-null  object
#  7   LSOA11CD     67087 non-null  object
#  8   MSOA11CD     67087 non-null  object
#  9   WD11CD_BF    67087 non-null  object
#  10  WD11NM_BF    67087 non-null  object
#  11  LAD11CD      67087 non-null  object
#  12  LAD11NM      67087 non-null  object
#  13  RGN11CD      67087 non-null  object
#  14  RGN11NM      67087 non-null  object
#  15  LSOA11NM     67087 non-null  object
#  16  MSOA11NM     67087 non-null  object
#  17  USUALRES     67087 non-null  float64
#  18  HHOLDRES     67087 non-null  float64
#  19  COMESTRES    67087 non-null  float64
#  20  POPDEN       67087 non-null  float64
#  21  HHOLDS       67087 non-null  float64
#  22  AVHHOLDSZ    67087 non-null  float64
#  23  Zone         67087 non-null  float64
# dtypes: float64(11), geometry(1), int64(1), object(11)
# memory usage: 12.9+ MB

# %%
# Plot the merged shapes
# Create a figure and axis
fig, ax = plt.subplots(1,1, figsize=(25,10))

London_zones_airbnb_22.to_crs('epsg:27700').plot(column='Zone',cmap='OrRd', ax=ax)

# Add the Elizabeth Line stations
el_station.to_crs('epsg:27700').plot(edgecolor='green', facecolor='white', ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Group the data by the "Zone" column
zone_grouped_London_22 = London_zones_airbnb_22.groupby('Zone')

# Calculate the median of each group
zone_grouped_London_22 = London_zones_airbnb_22.groupby(['Zone'])
zone_grouped_price_22 = zone_grouped_London_22['price'].median()
zone_grouped_price_22
# Out:
# Zone
# 1.0    168.0
# 2.0     95.0
# 3.0     80.0
# 4.0     70.0
# 5.0     69.0
# 6.0     72.0
# Name: price, dtype: float64

# %%
# Do the same process to get the median price per zone in 2020 listings
# Check the airbnb listings in 2020
airbnb_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71329 entries, 0 to 74187
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            71327 non-null  float64
#  1   listing_url                                   71328 non-null  object
#  2   scrape_id                                     71328 non-null  object
#  3   last_scraped                                  71328 non-null  object
#  4   name                                          71310 non-null  object
#  5   description                                   71329 non-null  object
#  6   neighborhood_overview                         47133 non-null  object
#  7   picture_url                                   71329 non-null  object
#  8   host_id                                       71329 non-null  float64
#  9   host_url                                      71329 non-null  object
#  10  host_name                                     71320 non-null  object
#  11  host_since                                    71320 non-null  object
#  12  host_location                                 71155 non-null  object
#  13  host_about                                    41198 non-null  object
#  14  host_response_time                            36350 non-null  object
#  15  host_response_rate                            36348 non-null  object
#  16  host_acceptance_rate                          49629 non-null  object
#  17  host_is_superhost                             71318 non-null  object
#  18  host_thumbnail_url                            71318 non-null  object
#  19  host_picture_url                              71318 non-null  object
#  20  host_neighbourhood                            54938 non-null  object
#  21  host_listings_count                           71316 non-null  float64
#  22  host_total_listings_count                     71318 non-null  object
#  23  host_verifications                            71327 non-null  object
#  24  host_has_profile_pic                          71318 non-null  object
#  25  host_identity_verified                        71318 non-null  object
#  26  neighbourhood                                 47132 non-null  object
#  27  neighbourhood_cleansed                        71327 non-null  object
#  28  neighbourhood_group_cleansed                  2 non-null      float64
#  29  latitude                                      71327 non-null  float64
#  30  longitude                                     71327 non-null  float64
#  31  property_type                                 71327 non-null  object
#  32  room_type                                     71327 non-null  object
#  33  accommodates                                  71327 non-null  float64
#  34  bathrooms                                     2 non-null      float64
#  35  bathrooms_text                                71184 non-null  object
#  36  bedrooms                                      67118 non-null  object
#  37  beds                                          70548 non-null  float64
#  38  amenities                                     71327 non-null  object
#  39  price                                         71327 non-null  object
#  40  minimum_nights                                71327 non-null  float64
#  41  maximum_nights                                71327 non-null  object
#  42  minimum_minimum_nights                        71327 non-null  float64
#  43  maximum_minimum_nights                        71327 non-null  float64
#  44  minimum_maximum_nights                        71327 non-null  float64
#  45  maximum_maximum_nights                        71327 non-null  object
#  46  minimum_nights_avg_ntm                        71327 non-null  object
#  47  maximum_nights_avg_ntm                        71327 non-null  float64
#  48  calendar_updated                              2 non-null      float64
#  49  has_availability                              71327 non-null  object
#  50  availability_30                               71327 non-null  float64
#  51  availability_60                               71327 non-null  float64
#  52  availability_90                               71327 non-null  float64
#  53  availability_365                              71327 non-null  float64
#  54  calendar_last_scraped                         71325 non-null  object
#  55  number_of_reviews                             71327 non-null  object
#  56  number_of_reviews_ltm                         71327 non-null  float64
#  57  number_of_reviews_l30d                        71327 non-null  float64
#  58  first_review                                  52831 non-null  object
#  59  last_review                                   52831 non-null  object
#  60  review_scores_rating                          51308 non-null  float64
#  61  review_scores_accuracy                        51259 non-null  float64
#  62  review_scores_cleanliness                     51268 non-null  float64
#  63  review_scores_checkin                         51220 non-null  float64
#  64  review_scores_communication                   51260 non-null  float64
#  65  review_scores_location                        51223 non-null  float64
#  66  review_scores_value                           51222 non-null  float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              71325 non-null  object
#  69  calculated_host_listings_count                71325 non-null  float64
#  70  calculated_host_listings_count_entire_homes   71325 non-null  float64
#  71  calculated_host_listings_count_private_rooms  71325 non-null  float64
#  72  calculated_host_listings_count_shared_rooms   71325 non-null  float64
#  73  reviews_per_month                             52829 non-null  float64
# dtypes: float64(34), object(40)
# memory usage: 40.8+ MB

# %%
# Drop columns that are entirely null or None
airbnb_20 = airbnb_20.dropna(axis=1, how='all')

# %%
# Check the price data since it is object
airbnb_20.price
# Out:
# 0         $87.00
# 1         $49.00
# 2         $75.00
# 3        $208.00
# 4        $150.00
#           ...
# 74183     $55.00
# 74184    $200.00
# 74185    $150.00
# 74186     $23.00
# 74187     $80.00
# Name: price, Length: 71329, dtype: object

# %%
# Replace the unit and change it to numerical for further calculations
airbnb_20['price'] = airbnb_20['price'].apply(lambda x: float(re.sub(r'[$,]', '', x)) if isinstance(x, str) else x)
airbnb_20.price
# Out:
# 0         87.0
# 1         49.0
# 2         75.0
# 3        208.0
# 4        150.0
#          ...
# 74183     55.0
# 74184    200.0
# 74185    150.0
# 74186     23.0
# 74187     80.0
# Name: price, Length: 71329, dtype: float64

# %%
# Extract the needed information
airbnb_20_price = airbnb_20.loc[:,['id', 'price', 'longitude', 'latitude']]
airbnb_20_price.head()
# Out:
#         id  price  longitude  latitude
# 0  11551.0   87.0   -0.11732  51.46225
# 1  13913.0   49.0   -0.11121  51.56802
# 2  15400.0   75.0   -0.16898  51.48796
# 3  17402.0  208.0   -0.14094  51.52195
# 4  17506.0  150.0   -0.19743  51.47935

# %%
# Make the airbnb 2020 data as point pattern
airbnb_20_point = gpd.GeoDataFrame(airbnb_20_price, 
      geometry=gpd.points_from_xy(airbnb_20_price.longitude, airbnb_20_price.latitude, crs='epsg:4326'))

# Change the CRS to EPSG 27700
airbnb_20_point = airbnb_20_point.to_crs('EPSG:27700')

# %%
# Check the data
airbnb_20_point.sample(n=10,random_state=100)
# Out:
#                id  price  longitude  latitude                       geometry
# 41036  28238803.0  189.0   -0.16187  51.49547  POINT (527697.762 178993.504)
# 57854  38272207.0  160.0   -0.19115  51.49182  POINT (525675.356 178536.980)
# 22813  17892120.0   76.0   -0.14274  51.48980  POINT (529041.641 178396.498)
# 52887  35563579.0   40.0   -0.05601  51.53790  POINT (534920.497 183901.658)
# 32340  22653411.0  165.0   -0.12572  51.44947  POINT (530337.995 173941.805)
# 27106  20111144.0  100.0   -0.08622  51.38291  POINT (533275.875 166611.218)
# 41752  28719473.0   75.0   -0.13950  51.59724  POINT (528962.698 190349.989)
# 48199  32812673.0  335.0   -0.12545  51.55936  POINT (530043.779 186162.419)
# 59486  39050798.0   55.0    0.01247  51.48231  POINT (539839.435 177848.394)
# 21379  16944003.0   63.0   -0.00365  51.50764  POINT (538643.366 180634.481)

# %%
# Check the column names
airbnb_20_point.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 71329 entries, 0 to 74187
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         71327 non-null  float64
#  1   price      71327 non-null  float64
#  2   longitude  71327 non-null  float64
#  3   latitude   71327 non-null  float64
#  4   geometry   71329 non-null  geometry
# dtypes: float64(4), geometry(1)
# memory usage: 3.3 MB

# %%
# Fail to plot the Airbnb listing points in London boundaries
# Drop the problematic rows
airbnb_20_price.drop(airbnb_20_price[(airbnb_20_price.latitude==2) | (airbnb_20_price.longitude==2)|(airbnb_20_price.latitude.isna())|(airbnb_20_price.longitude.isna())].index.array, axis=0, inplace=True)

# %%
# Make the airbnb 2020 data as point pattern
airbnb_20_point = gpd.GeoDataFrame(airbnb_20_price, 
      geometry=gpd.points_from_xy(airbnb_20_price.longitude, airbnb_20_price.latitude, crs='epsg:4326'))

# Change the CRS to EPSG 27700
airbnb_20_point = airbnb_20_point.to_crs('EPSG:27700')

# %%
# Check the data
airbnb_20_point.sample(n=10,random_state=100)
# Out:
#                id  price  longitude  latitude                       geometry
# 44845  30580499.0   35.0   -0.14723  51.47708  POINT (528765.732 176974.094)
# 57193  37931556.0  365.0   -0.15052  51.48747  POINT (528508.083 178123.720)
# 65560  41528978.0   75.0   -0.13639  51.53228  POINT (529362.180 183131.630)
# 18428  14939248.0   38.0   -0.22598  51.54856  POINT (523104.508 184787.585)
# 72160  44208162.0   42.0   -0.09474  51.46174  POINT (532455.087 175361.791)
# 1335     707338.0   35.0   -0.14766  51.39412  POINT (528969.123 167747.981)
# 13686  11435597.0  100.0   -0.05379  51.50554  POINT (535170.163 180307.236)
# 71366  43967718.0  155.0   -0.01986  51.50117  POINT (537537.958 179884.445)
# 28344  20767939.0   49.0   -0.31094  51.51870  POINT (517290.561 181327.529)
# 63140  40520426.0  300.0   -0.11240  51.52957  POINT (531033.838 182872.923)

# %%
# Plot the Airbnb listing points in London boundaries
# Create a figure and axis
fig, ax = plt.subplots(1,1, figsize=(25,10))

# Plot the OA London boundaries
London.to_crs(epsg=27700).plot(edgecolor='lightblue', facecolor='white', ax=ax)

# Plot the 2020 airbnb listing points and coloured by their price
airbnb_20_point.to_crs(epsg=27700).plot(column='price', cmap='viridis', alpha=0.25, markersize=1, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Join the airbnb listing points that are within the boundaries

London_zones_airbnb_20 = gpd.sjoin(airbnb_20_point,London_zones, how="left")

London_zones_airbnb_20.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 71325 entries, 0 to 74187
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           71325 non-null  float64
#  1   price        71325 non-null  float64
#  2   longitude    71325 non-null  float64
#  3   latitude     71325 non-null  float64
#  4   geometry     71325 non-null  geometry
#  5   index_right  71288 non-null  float64
#  6   OA11CD       71288 non-null  object
#  7   LSOA11CD     71288 non-null  object
#  8   MSOA11CD     71288 non-null  object
#  9   WD11CD_BF    71288 non-null  object
#  10  WD11NM_BF    71288 non-null  object
#  11  LAD11CD      71288 non-null  object
#  12  LAD11NM      71288 non-null  object
#  13  RGN11CD      71288 non-null  object
#  14  RGN11NM      71288 non-null  object
#  15  LSOA11NM     71288 non-null  object
#  16  MSOA11NM     71288 non-null  object
#  17  USUALRES     71288 non-null  float64
#  18  HHOLDRES     71288 non-null  float64
#  19  COMESTRES    71288 non-null  float64
#  20  POPDEN       71288 non-null  float64
#  21  HHOLDS       71288 non-null  float64
#  22  AVHHOLDSZ    71288 non-null  float64
#  23  Zone         71288 non-null  float64
# dtypes: float64(12), geometry(1), object(11)
# memory usage: 13.6+ MB

# %%
# Plot the merged shapes
# Create a figure and axis
fig, ax = plt.subplots(1,1, figsize=(25,10))

London_zones_airbnb_20.to_crs('epsg:27700').plot(column='Zone',
                                                 cmap='BuPu', 
                                                 ax=ax, 
                                                 legend=True)

# Add the Elizabeth Line stations
track.plot(ax=ax, edgecolor='steelblue', linewidth=3.0)
stations.plot(ax=ax, column='STATION_NA', color='steelblue')



#set a legend
mylabels= ['Stations', 'Elizabeth Line']
ax.legend(track, loc='lower right', frameon=False, labels=mylabels)

# Set the x and y limits
ax.set_xlim(501000,563000)
ax.set_ylim(155000,202000)

#titles and plot
plt.axis('off')
plt.suptitle("Location of listings", x=0.39, y=0.95, size=24, **tfont)
plt.title("per zone", loc='left', size=16,**afont)
plt.savefig("Location_perzone.png", bbox_inches = 'tight')
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# /tmp/ipykernel_2515/2158457365.py:18: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend(track, loc='lower right', frameon=False, labels=mylabels)

# %%
# Group the data by the "Zone" column
zone_grouped_London_20 = London_zones_airbnb_20.groupby('Zone')

# Calculate the median of each group
zone_grouped_London_20 = London_zones_airbnb_20.groupby(['Zone'])
zone_grouped_price_20 = zone_grouped_London_20['price'].median()
zone_grouped_price_20
# Out:
# Zone
# 1.0    115.0
# 2.0     79.0
# 3.0     60.0
# 4.0     50.0
# 5.0     45.0
# 6.0     50.0
# Name: price, dtype: float64

# %%
# Join these two years airbnb listing price
zone_grouped_price = pd.concat([zone_grouped_price_20, zone_grouped_price_22], axis=1)

# Rename the columns
zone_grouped_price.columns = ['2020_median_price', '2022_median_price']

# Reset the index of the results to avoid zones be index
zone_grouped_price = zone_grouped_price.reset_index()

# Calculate the difference between these two years
zone_grouped_price = zone_grouped_price.assign(Difference=zone_grouped_price['2022_median_price']-zone_grouped_price['2020_median_price'])

# Calculate the Variation between these two years
zone_grouped_price['Variation'] = zone_grouped_price['Difference'] / zone_grouped_price['2022_median_price']

# Change the variation in 2 decimal places
zone_grouped_price['Variation'] = zone_grouped_price['Variation'].apply(lambda x: round(x, 2))

# Change the zone number into integer
zone_grouped_price['Zone'] = zone_grouped_price['Zone'].apply(lambda x: int(x))

# Sort the columns by variation
zone_grouped_price = zone_grouped_price.sort_values(by="Variation", ascending=False)

zone_grouped_price
# Out:
#    Zone  2020_median_price  2022_median_price  Difference  Variation
# 4     5               45.0               69.0        24.0       0.35
# 0     1              115.0              168.0        53.0       0.32
# 5     6               50.0               72.0        22.0       0.31
# 3     4               50.0               70.0        20.0       0.29
# 2     3               60.0               80.0        20.0       0.25
# 1     2               79.0               95.0        16.0       0.17

# %%
# Plot the variation per zone
sns.set_palette("colorblind")
sns.barplot(data=zone_grouped_price, x='Variation', y='Zone', color='xkcd:purple', order=zone_grouped_price.sort_values('Variation', ascending = False).Zone, orient='h')

# Label the x and y axes
plt.xlabel("The variation/percentage of median prices")
plt.ylabel("Zone", rotation=0)

# Show the chart
plt.show()
